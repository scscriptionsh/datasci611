# %% [markdown]
# Web Scraping
# ============
#
# Web scraping is an ugly name for a reasonable thing: some data is available via your browser and you want to get it into some kind of reasonable shape without literally copying and pasting everything into a spreadsheet somewhere.
#
# You might think that if you work with a company that wants you to do data science that you'll always get nice data from them in the form of a database connection or just a csv file. That is often not the case. Getting database accesss can be a politically challenging thing in some situations (database admins can be quite protective of their territory). Sometimes its better and easier in that situation to just scrape the data from the web front end of whatever system you're working on. This is often good enough for a prototype which can then be leveraged for more formal access to the data.
#
# Language Selection
# ==================
#
# As we know from various lectures, your browser is just a fancy HTTP protocol client: it makes requests and renders the response (sometimes making multiple requests in the back and in response to local events or even as part of its major rendering strategy). Therefor we can use any language to do web scraping as long as it supports issueing HTTP requests and receiving the body of the response back. In fact, there are very capable command line tools (curl, wget) in Unix that you can call from almost any language at all to serve this purpose.
#
# But once you get the data you want you don't want to have to grub though it character by character to get what you want. Its very helpful if your language of choice makes it easy to parse the resulting HTML or JSON data into a native data structure so that you can more easily and reliably extract the data. Both R and Python provide packages to this end. Today we're going to use Python but similar workflows are available in R or Javascript or Java or whatever. Its a common task.
#
# Don't DDOS
# ==========
#
# DDOS stands for "distributed denial of service" and its a sort of attack you can launch at a website or other web service. In a DDOS you flood a server with millions of requests a second which has the tendency to bring most servers down. At the very least, it tends to prevent legitimate traffic from accessing the service: they end up having to wait in line behind all the garbage traffic.
#
# Many websites, therefore, detect unusual access patterns and block IP addresses that make too frequent requests. Therefore, even when writing the simplest scraper, it pays to
#
# 1. Make sure you don't issue too many requests too fast
# 2. Cache the results of requests so that you never request the same page over and over (say during testing)
#
# This is actually pretty easy to set up, so there is no reason not to do it.
#
# BeautifulSoup
# =============
#
# We're going to use BeautifulSoup:
#
# ```
# RUN apt update && apt-get install -y emacs openssh-server python3-pip
# RUN pip3 install beautifulsoup4  pandas numpy pandasql
# ```
#
# Back in the day people used to write HTML by hand and a lot of it was pretty bad (it failed to follow all the rules). BeautifulSoup will make a decent effort to figure out what was intended, even if the HTML isn't perfect. This is handy.
#
# Getting Started
# ===============
#
# Let's begin by learning how to make HTTP requests.

# %%
from requests import get as get_raw


get_raw("http://tmbw.net/wiki/Lyrics:Window")
# Out:
# <Response [200]>

# %% [markdown]
# There is that "200" HTTP status code. That tells us that the request succeeded. Any other code is probably an error, but you'll likely see 404 (page not found) and 500 (internal server error). 404 almost always means what it says, but 500 is a coy way of saying "you can't access this resources and I'm not even going to tell you whether or not it exists." Its outside of the scope of this lecture to discuss how to scrape "private" pages, but it is possible: you just have to add the right stuff to your request header. This is, I believe, something of a legal grey area so tread lightly.
#
# Let's get a little more fun information from the page.

# %%
get_raw("http://tmbw.net/wiki/Lyrics:Window").content[0:500]
# Out:
# b'<!DOCTYPE html>\n<html lang="en" dir="ltr" class="client-nojs">\n<head>\n<meta charset="UTF-8" />\n<title>Lyrics:Window - TMBW: The They Might Be Giants Knowledge Base</title>\n<meta name="generator" content="MediaWiki 1.25.0" />\n<link rel="alternate" type="application/x-wiki" title="Edit" href="/wiki/index.php?title=Lyrics:Window&amp;action=edit" />\n<link rel="edit" title="Edit" href="/wiki/index.php?title=Lyrics:Window&amp;action=edit" />\n<link rel="apple-touch-icon" href="/apple-touch-icon.png" />'

# %% [markdown]
# I've truncated the output we got back, but you can see that the "content" we've received back from the server is a real life HTML document (represented as a string). Our next conceptual step is to parse this and search it for the data we want. But before we do that, let's take care of caching our results so we don't rudely make too many requests against this server.

# %%
from hashlib import md5 as hash_raw

def hash(s):
    return hash_raw(s.encode()).hexdigest()

[hash("http://tmbw.net/wiki/Lyrics:Window"),
 hash("http://tmbw.net/wiki/Lyrics:Window"),
 hash("http://tmbw.net/wiki/Lyrics:SnailShell")]
# Out:
# ['a8fe29d5e9cb70e54efcc7ae382a2519',
#  'a8fe29d5e9cb70e54efcc7ae382a2519',
#  'ee7e1fd80caa65cd936de2baf6a9a96c']

# %% [markdown]
# We've created a function here which turns our URL into a unique string. We'll save the results of any request to a file named after this string whenever we make a request. But first we'll see if such a file exists and if it does, we'll load the response from disk instead of issuing a request. If we ever want to clear our cache we can just delete the contents of our cache directory.
#
# Caching like this will also tend to speed up complicated scraping jobs (which often revisit the same page repeatedly as they "crawl" a website).

# %%
import os

cachedir = "lecture_scrape_cache"
if not os.path.isdir(cachedir):
    os.mkdir(cachedir);

def to_cache_name(url):
    return "./{}/{}".format(cachedir, hash(url));

def read_file(s):
    with open(s,'r') as fd:
        return fd.read();
    
def write_file(s, content):
    with open(s,'w') as fd:
        fd.write(content)
    return s;

verbose = True;

def get(url):
    cache_name = to_cache_name(url);
    if os.path.isfile(cache_name):
        if verbose:
            print("Cache hit: {}".format(url));
        return read_file(cache_name);
    else:
        if verbose:
            print("Cache miss: {}".format(url));
        content = get_raw(url).content.decode();
        write_file(cache_name, content);
        return content;

# %%
! rm -f lecture_scrape_cache/*

get("http://tmbw.net/wiki/Lyrics:Window")[0:500]
# Out:
# Cache miss: http://tmbw.net/wiki/Lyrics:Window
# '<!DOCTYPE html>\n<html lang="en" dir="ltr" class="client-nojs">\n<head>\n<meta charset="UTF-8" />\n<title>Lyrics:Window - TMBW: The They Might Be Giants Knowledge Base</title>\n<meta name="generator" content="MediaWiki 1.25.0" />\n<link rel="alternate" type="application/x-wiki" title="Edit" href="/wiki/index.php?title=Lyrics:Window&amp;action=edit" />\n<link rel="edit" title="Edit" href="/wiki/index.php?title=Lyrics:Window&amp;action=edit" />\n<link rel="apple-touch-icon" href="/apple-touch-icon.png" />'

# %%
get("http://tmbw.net/wiki/Lyrics:Window")[0:500]
# Out:
# Cache hit: http://tmbw.net/wiki/Lyrics:Window
# '<!DOCTYPE html>\n<html lang="en" dir="ltr" class="client-nojs">\n<head>\n<meta charset="UTF-8" />\n<title>Lyrics:Window - TMBW: The They Might Be Giants Knowledge Base</title>\n<meta name="generator" content="MediaWiki 1.25.0" />\n<link rel="alternate" type="application/x-wiki" title="Edit" href="/wiki/index.php?title=Lyrics:Window&amp;action=edit" />\n<link rel="edit" title="Edit" href="/wiki/index.php?title=Lyrics:Window&amp;action=edit" />\n<link rel="apple-touch-icon" href="/apple-touch-icon.png" />'

# %% [markdown]
# I also like to do one more "polite" thing which web scraping, which is to limit the number of requests I make by putting a delay before each access.

# %%
from time import sleep

get_delay = 1; # second
def get(url):
    cache_name = to_cache_name(url);
    if os.path.isfile(cache_name):
        print("Cache hit: {}".format(url));
        return read_file(cache_name);
    else:
        print("Cache miss: {}".format(url));
        sleep(get_delay);
        content = get_raw(url).content.decode();
        write_file(cache_name, content);
        return content;

# %% [markdown]
# By modifying the delay we can change how polite we are. 1 Second is probably a bit conservative.

# %%
get_delay = 0.1;

# %% [markdown]
# Now we are ready to start scraping in earnest. Let's look at a typical page as an example:
# [http://tmbw.net/wiki/Lyrics:Window](http://tmbw.net/wiki/Lyrics:Window). Once we've opened the page we can inspect the HTML element there and decide what we want to get. In this example I want to extract the song title, the band, the year and the lyrics themselves. The way it works when you scrape is you try to find some unique properties of the elements you're interested in grabbing. Then you can use BeautifulSoup to search for those elements and extract the results from them.
#
# In this case everything we want is in the "lyricstable" table element. And then the data we want is in a series of rows. This is actually a little bit tricky of a scraping job because the individual rows don't tell us all that much about what they have in them. We'll have to rely on the order in which they appear which seems brittle. We'll try to do a little better than that but let's begin with the simplest strategy.

# %%
from bs4 import BeautifulSoup as bs
def parse_html(html):
    return bs(html);

def get_document(url):
    return parse_html(get(url));

repr(get_document("http://tmbw.net/wiki/Lyrics:Window"))[0:100]
# Out:
# Cache hit: http://tmbw.net/wiki/Lyrics:Window
# '<!DOCTYPE html>\n<html class="client-nojs" dir="ltr" lang="en">\n<head>\n<meta charset="utf-8"/>\n<title'

# %%
def get_song_table(url):
    doc = get_document(url);
    return doc.find("table",class_="lyricstable");

# %%
test_url = "http://tmbw.net/wiki/Lyrics:Window"
get_song_table(test_url)
# Out:
# Cache hit: http://tmbw.net/wiki/Lyrics:Window
# <table align="center" cellspacing="3" class="lyricstable">
# <tr>
# <td style="text-align:right;"><b>Window</b>
# </td></tr>
# <tr>
# <td style="text-align:right;"><b>By: <a href="/wiki/They_Might_Be_Giants" title="They Might Be Giants">They Might Be Giants</a></b>
# </td></tr>
# <tr>
# <td style="text-align:right;"><b>Year: <a href="/wiki/Category:Songs_Released_In_1994" title="Category:Songs Released In 1994">1994</a></b>
# </td></tr>
# <tr>
# <td><div class="lyrics-table" style="white-space: pre-wrap;">
# <p>Look at all the people in the window
# I'm checking out the people in the window
# I was uncomfortable
# Now I'm uncomfortable
# The trouble I encountered when I thought it was, it was a window
# </p><p>It was a catalog
# Of many women, men
# The window
# Window
# Window
# </p><p>Look at all the people in the window
# I'm checking out the people in the window
# I was uncomfortable
# Now I'm uncomfortable
# The trouble I encountered when I thought it was, it was a window
# </p>
# </div>
# </td></tr></table>

# %% [markdown]
# This looks like the data we want. First the easy thing: the lyrics. These are at least in a unique div with class "lyrics-table". The other elements are in "td" tags and I think the best bet we've got is to use their "style" attribute (they are all right aligned).

# %%
def get_song_data(url):
    tbl = get_song_table(url);
    out = {};
    lyrics = tbl.find("div",class_="lyrics-table").text.strip().split("\n");
    tds = tbl.find_all("td", attrs={"style":"text-align:right;"})
    out["title"] = tds[0].text.strip();
    out["by"] = tds[1].text.strip().split(":")[1];
    out["year"] = tds[2].text.strip().split(":")[1];
    out["lyrics"] = lyrics;
    return out
get_song_data(test_url)
# Out:
# Cache hit: http://tmbw.net/wiki/Lyrics:Window
# {'title': 'Window',
#  'by': ' They Might Be Giants',
#  'year': ' 1994',
#  'lyrics': ['Look at all the people in the window',
#   "I'm checking out the people in the window",
#   'I was uncomfortable',
#   "Now I'm uncomfortable",
#   'The trouble I encountered when I thought it was, it was a window',
#   'It was a catalog',
#   'Of many women, men',
#   'The window',
#   'Window',
#   'Window',
#   'Look at all the people in the window',
#   "I'm checking out the people in the window",
#   'I was uncomfortable',
#   "Now I'm uncomfortable",
#   'The trouble I encountered when I thought it was, it was a window']}

# %% [markdown]
# While I worked on this I had to iterate on these functions over and over. Because my code transparently caches the results I only had to make a single http request near the top of the lecture. Let's try another page to see if things work the way we expect.

# %%
get_song_data("http://tmbw.net/wiki/Lyrics:A_Self_Called_Nowhere")
# Out:
# Cache hit: http://tmbw.net/wiki/Lyrics:A_Self_Called_Nowhere
# {'title': 'A Self Called Nowhere',
#  'by': ' They Might Be Giants',
#  'year': ' 1994',
#  'lyrics': ["I'm sitting on the curb",
#   'Of the empty parking lot',
#   'Of the store where they let me play the organ',
#   "I'm waiting for my ride",
#   'But I want to wait inside',
#   'The store where they let me play the organ',
#   "But I'm thinking of a wooden chair",
#   'In the room at the top of the stair',
#   "And I'm looking down the stairwell",
#   'At the vanishing dot',
#   'On the map of the spot',
#   'Let me take you there',
#   'The dotted line',
#   'Surrounding the mind',
#   'Of a self called nowhere',
#   'It\'s a thing named "it"',
#   'In a bottomless pit',
#   "You can't see it there",
#   'The sunken head',
#   'That lies in the bed',
#   'Of a self called nowhere',
#   'Standing in my yard',
#   'Where they tore down the garage',
#   'To make room for the torn down garage',
#   "I'm looking for my car",
#   'But I must have sold my car',
#   'When I needed to buy an electric organ',
#   "But I'm thinking of a wooden chair",
#   'In the room at the top of the stair',
#   "And I'm looking down the stairwell",
#   'At the vanishing dot',
#   'On the map of the spot',
#   'Let me take you there',
#   'The dotted line',
#   'Surrounding the mind',
#   'Of a self called nowhere',
#   'It\'s a thing named "it"',
#   'In a bottomless pit',
#   "You can't see it there",
#   'The sunken head',
#   'That lies in the bed',
#   'Of a self called nowhere',
#   'Nowhere',
#   'The vanishing dot',
#   'On the map of the spot',
#   'Let me take you there',
#   'The dotted line',
#   'Surrounding the mind',
#   'Of a self called nowhere',
#   'It\'s a thing named "it"',
#   'In a bottomless pit',
#   "You can't see it there",
#   'The sunken head',
#   'That lies in the bed',
#   'Of a self called...']}

# %% [markdown]
# Recursive Scraping
# ==================
#
# Its not atypical for us to want to scrape a large number of similar pages. In this example we might be interest in all the lyrics and information for all of TMBG's songs ever. We could find these urls one by one and pass them to our scraper, but that is a lot of work. The thing to do here is to let the structure of the web page guide us. Let'se see if we can figure out how we can use the page itself to get the urls we need.
#
# If we visit the main page of the site we can see there is a discography page. This looks like a great place to start, since it lists all of their albums of any type. If each album page we reach by this page has the song urls somewhere, then we're in business.
#
# Sure enough, each release page contains a track listing section with links to the lyrics pages. It seems like we can extract a list of lyrics links from each page. These pages might be formatted different on each page, so let's rely on something that seems pretty solid: a link to a lyrics page is an "a" element with "http://tmbw.net/wiki/Lyrics:" as the first part of the url.
#
# But first, let's write a scraper to get the album list from the discography page.
#
# Discography
# -----------

# %%
def get_album_list(url):
    doc = get_document(url);
    discog_table = doc.find("table", id = "discog");
    rows = discog_table.find_all("tr");
    def process_row(row):
        vals = row.find_all("td");
        year = vals[0].text.strip();
        album_url = vals[1].find("a")['href']
        title = vals[1].text.strip();
        return {"year":int(year), "title":title, "url":"http://tmbw.net"+album_url};
    return [ process_row(row) for row in rows if len(row.find_all("td")) >= 2 ];

get_album_list("http://tmbw.net/wiki/Discography")[0:4]
# Out:
# Cache hit: http://tmbw.net/wiki/Discography
# [{'year': 1985,
#   'title': 'Wiggle Diskette',
#   'url': 'http://tmbw.net/wiki/Wiggle_Diskette'},
#  {'year': 1985,
#   'title': '1985 Demo Tape',
#   'url': 'http://tmbw.net/wiki/1985_Demo_Tape'},
#  {'year': 1986,
#   'title': 'They Might Be Giants - Joshua Fried Split Single',
#   'url': 'http://tmbw.net/wiki/They_Might_Be_Giants_-_Joshua_Fried_Split_Single'},
#  {'year': 1986,
#   'title': 'They Might Be Giants',
#   'url': 'http://tmbw.net/wiki/They_Might_Be_Giants_(Album)'}]

# %% [markdown]
# Note that above we put the domain back on the url: web pages typically use "relative" urls to link within themselves but we need the whole thing.
#
# Track Lists
# -----------
#
# Now that we have our album we need a scraper to scrape the track list out of each album. The easiest thing to do here is to find all the urls that have the string "http://tmbw.net/wiki/Lyrics:" in it.

# %%
def scrape_lyrics_pages(url):
    doc = get_document(url);
    out = [];
    for link in doc.find_all("a"):
        if link.has_key("href") and "wiki/Lyrics:" in link['href']:
            out.append("http://tmbw.net"+link['href']);
    return out;

scrape_lyrics_pages("http://tmbw.net/wiki/Apollo_18")
# Out:
# Cache miss: http://tmbw.net/wiki/Apollo_18
# /usr/local/lib/python3.8/dist-packages/bs4/element.py:1970: UserWarning: has_key is deprecated. Use has_attr("href") instead.
#   warnings.warn('has_key is deprecated. Use has_attr("%s") instead.' % (
# ['http://tmbw.net/wiki/Lyrics:Dig_My_Grave',
#  'http://tmbw.net/wiki/Lyrics:I_Palindrome_I',
#  'http://tmbw.net/wiki/Lyrics:She%27s_Actual_Size',
#  'http://tmbw.net/wiki/Lyrics:My_Evil_Twin',
#  'http://tmbw.net/wiki/Lyrics:Mammal',
#  'http://tmbw.net/wiki/Lyrics:The_Statue_Got_Me_High',
#  'http://tmbw.net/wiki/Lyrics:Spider',
#  'http://tmbw.net/wiki/Lyrics:The_Guitar',
#  'http://tmbw.net/wiki/Lyrics:Dinner_Bell',
#  'http://tmbw.net/wiki/Lyrics:Narrow_Your_Eyes',
#  'http://tmbw.net/wiki/Lyrics:Hall_Of_Heads',
#  'http://tmbw.net/wiki/Lyrics:Which_Describes_How_You%27re_Feeling',
#  'http://tmbw.net/wiki/Lyrics:See_The_Constellation',
#  'http://tmbw.net/wiki/Lyrics:If_I_Wasn%27t_Shy',
#  'http://tmbw.net/wiki/Lyrics:Turn_Around',
#  'http://tmbw.net/wiki/Lyrics:Hypnotist_Of_Ladies',
#  'http://tmbw.net/wiki/Lyrics:Everything_Is_Catching_On_Fire',
#  'http://tmbw.net/wiki/Lyrics:Fingertips_(Banjo)',
#  'http://tmbw.net/wiki/Lyrics:I_Hear_The_Wind_Blow',
#  'http://tmbw.net/wiki/Lyrics:Hey_Now_Everybody',
#  'http://tmbw.net/wiki/Lyrics:Who%27s_That_Standing_Out_The_Window%3F',
#  'http://tmbw.net/wiki/Lyrics:I_Found_A_New_Friend_Underneath_My_Pillow',
#  'http://tmbw.net/wiki/Lyrics:Come_On_And_Wreck_My_Car',
#  'http://tmbw.net/wiki/Lyrics:Aren%27t_You_The_Guy_Who_Hit_Me_In_The_Eye%3F',
#  'http://tmbw.net/wiki/Lyrics:Please_Pass_The_Milk',
#  'http://tmbw.net/wiki/Lyrics:Leave_Me_Alone',
#  'http://tmbw.net/wiki/Lyrics:Who%27s_Knocking_On_The_Wall%3F',
#  'http://tmbw.net/wiki/Lyrics:All_Alone,_All_By_Myself',
#  'http://tmbw.net/wiki/Lyrics:What%27s_That_Blue_Thing_Doing_Here%3F',
#  'http://tmbw.net/wiki/Lyrics:Something_Grabbed_Ahold_Of_My_Hand',
#  'http://tmbw.net/wiki/Lyrics:I_Don%27t_Understand_You',
#  'http://tmbw.net/wiki/Lyrics:I_Heard_A_Sound',
#  'http://tmbw.net/wiki/Lyrics:Mysterious_Whisper',
#  'http://tmbw.net/wiki/Lyrics:The_Day_That_Love_Came_To_Play',
#  'http://tmbw.net/wiki/Lyrics:I%27m_Having_A_Heart_Attack',
#  'http://tmbw.net/wiki/Lyrics:Fingertips_(Whispered)',
#  'http://tmbw.net/wiki/Lyrics:I_Walk_Along_Darkened_Corridors',
#  'http://tmbw.net/wiki/Lyrics:Space_Suit']

# %% [markdown]
# Putting it All Together
# =======================
#
# We've not got:
#
# 1. Code to Scrape all the Album URLS
# 2. Code to Scrape the Tracklist from Each Album
# 3. Code to Scrape Lyric data from the Tracks
#
# So we just need to write a program that puts it all together. Its worth thinking a little about how to put our data together. One possibility is just a dataframe with columns:
#
# 1. year
# 2. album
# 3. song title
# 4. lyrics
#
# We could also encode the results as objects and just dump them as JSON. JSON can be more appropriate for this kind of data and we're already pretty familiar with dataframes, so let's do that. A JSON object is a collection of nested objects consisting of arrays, dictionaries and strings and numbers (the latter two unable to hold any sub objects, obviously). So our output format will be a list of objects with year, album and song title and then a lyrics sub-array with the lyrics as lines.
#
# Enter Make
# ==========
#
# With a task this simple we could write a function like this:

# %%
def scrape_tmbg_lyrics(discog_url):
    albums = get_album_list(discog_url);
    output = [];
    for album in albums:
        url = album['url'];
        tracks = scrape_lyrics_pages(url);
        for track in tracks:
            data = get_song_data(track);
            data['album'] = album['title'];
            output.append(data);
    return output;

# %%
scrape_tmbg_lyrics("http://tmbw.net/wiki/Discography")
# Out:
# Cache miss: http://tmbw.net/wiki/Discography
# Cache miss: http://tmbw.net/wiki/Wiggle_Diskette
# Cache miss: http://tmbw.net/wiki/Lyrics:Everything_Right_Is_Wrong
# Cache miss: http://tmbw.net/wiki/Lyrics:You%27ll_Miss_Me_(Demo_1)
# Cache miss: http://tmbw.net/wiki/1985_Demo_Tape
# Cache miss: http://tmbw.net/wiki/Lyrics:Put_Your_Hand_Inside_The_Puppet_Head_(Demo_3)
# Cache miss: http://tmbw.net/wiki/Lyrics:When_It_Rains_It_Snows_(Demo)
# Cache miss: http://tmbw.net/wiki/Lyrics:Number_Three_(1985_Demo)
# Cache miss: http://tmbw.net/wiki/Lyrics:Don%27t_Let%27s_Start_(1985_Demo)
# Cache miss: http://tmbw.net/wiki/Lyrics:You%27ll_Miss_Me_(Demo_2)
# Cache miss: http://tmbw.net/wiki/Lyrics:I_Hope_That_I_Get_Old_Before_I_Die_(Demo)
# Cache miss: http://tmbw.net/wiki/Lyrics:The_Biggest_One_(1985_Demo)
# Cache miss: http://tmbw.net/wiki/Lyrics:32_Footsteps
# Cache miss: http://tmbw.net/wiki/Lyrics:Boat_Of_Car_(1985_Demo)
# Cache miss: http://tmbw.net/wiki/Lyrics:Cowtown_(1985_Demo_2)
# Cache miss: http://tmbw.net/wiki/Lyrics:Chess_Piece_Face_(1985_Demo)
# Cache miss: http://tmbw.net/wiki/Lyrics:Rabid_Child
# Cache miss: http://tmbw.net/wiki/Lyrics:Youth_Culture_Killed_My_Dog_(1985_Demo)
# Cache miss: http://tmbw.net/wiki/Lyrics:Alienation%27s_For_The_Rich
# Cache miss: http://tmbw.net/wiki/Lyrics:The_Day_(Demo)
# Cache miss: http://tmbw.net/wiki/Lyrics:(She_Was_A)_Hotel_Detective_(1985_Demo)
# Cache miss: http://tmbw.net/wiki/Lyrics:Which_Describes_How_You%27re_Feeling_(Demo)
# Cache miss: http://tmbw.net/wiki/Lyrics:Toddler_Hiway
# Cache miss: http://tmbw.net/wiki/Lyrics:Become_A_Robot
# Cache miss: http://tmbw.net/wiki/Lyrics:I%27m_Def
# Cache miss: http://tmbw.net/wiki/Lyrics:Hell_Hotel
# Cache miss: http://tmbw.net/wiki/Lyrics:They_Might_Be_Giants_(Song)_(1985_Demo)
# Cache miss: http://tmbw.net/wiki/Lyrics:Nothing%27s_Going_To_Change_My_Clothes
# Cache miss: http://tmbw.net/wiki/They_Might_Be_Giants_-_Joshua_Fried_Split_Single
# Cache hit: http://tmbw.net/wiki/Lyrics:Put_Your_Hand_Inside_The_Puppet_Head_(Demo_3)
# Cache hit: http://tmbw.net/wiki/Lyrics:Number_Three_(1985_Demo)
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Day_(Demo)
# Cache miss: http://tmbw.net/wiki/They_Might_Be_Giants_(Album)
# Cache miss: http://tmbw.net/wiki/Lyrics:Everything_Right_Is_Wrong_Again
# Cache miss: http://tmbw.net/wiki/Lyrics:Put_Your_Hand_Inside_The_Puppet_Head
# Cache miss: http://tmbw.net/wiki/Lyrics:Number_Three
# Cache miss: http://tmbw.net/wiki/Lyrics:Don%27t_Let%27s_Start
# Cache miss: http://tmbw.net/wiki/Lyrics:Hide_Away_Folk_Family
# Cache hit: http://tmbw.net/wiki/Lyrics:32_Footsteps
# Cache hit: http://tmbw.net/wiki/Lyrics:Toddler_Hiway
# Cache hit: http://tmbw.net/wiki/Lyrics:Rabid_Child
# Cache miss: http://tmbw.net/wiki/Lyrics:Nothing%27s_Gonna_Change_My_Clothes
# Cache miss: http://tmbw.net/wiki/Lyrics:(She_Was_A)_Hotel_Detective
# Cache miss: http://tmbw.net/wiki/Lyrics:She%27s_An_Angel
# Cache miss: http://tmbw.net/wiki/Lyrics:Youth_Culture_Killed_My_Dog
# Cache miss: http://tmbw.net/wiki/Lyrics:Boat_Of_Car
# Cache miss: http://tmbw.net/wiki/Lyrics:Absolutely_Bill%27s_Mood
# Cache miss: http://tmbw.net/wiki/Lyrics:Chess_Piece_Face
# Cache miss: http://tmbw.net/wiki/Lyrics:I_Hope_That_I_Get_Old_Before_I_Die
# Cache hit: http://tmbw.net/wiki/Lyrics:Alienation%27s_For_The_Rich
# Cache miss: http://tmbw.net/wiki/Lyrics:The_Day
# Cache miss: http://tmbw.net/wiki/Lyrics:Rhythm_Section_Want_Ad
# Cache miss: http://tmbw.net/wiki/Lyrics:Don%27t_Let%27s_Start_(Single_Mix)
# Cache miss: http://tmbw.net/wiki/Lyrics:We%27re_The_Replacements
# Cache miss: http://tmbw.net/wiki/Lyrics:When_It_Rains_It_Snows
# Cache miss: http://tmbw.net/wiki/Lyrics:The_Famous_Polka
# Cache miss: http://tmbw.net/wiki/Lyrics:(She_Was_A)_Hotel_Detective_(Single_Mix)
# Cache miss: http://tmbw.net/wiki/Lyrics:For_Science
# Cache miss: http://tmbw.net/wiki/Lyrics:The_Biggest_One
# Cache miss: http://tmbw.net/wiki/Lyrics:Kiss_Me,_Son_Of_God_(Alternate_Version)
# Cache miss: http://tmbw.net/wiki/Lyrics:Mr._Klaw
# Cache miss: http://tmbw.net/wiki/Lyrics:Critic_Intro
# Cache miss: http://tmbw.net/wiki/Lyrics:Now_That_I_Have_Everything
# Cache miss: http://tmbw.net/wiki/Lyrics:Mainstream_U.S.A.
# Cache miss: http://tmbw.net/wiki/Lyrics:Fake_Out_In_Buenos_Aires
# Cache miss: http://tmbw.net/wiki/Lyrics:Greek_Number_Three
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_46/669600022.py in <module>
# ----> 1 scrape_tmbg_lyrics("http://tmbw.net/wiki/Discography")
#
# /tmp/ipykernel_46/2505707492.py in scrape_tmbg_lyrics(discog_url)
#       6         tracks = scrape_lyrics_pages(url);
#       7         for track in tracks:
# ----> 8             data = get_song_data(track);
#       9             data['album'] = album['title'];
#      10             output.append(data);
#
# /tmp/ipykernel_46/2767622724.py in get_song_data(url)
#       2     tbl = get_song_table(url);
#       3     out = {};
# ----> 4     lyrics = tbl.find("div",class_="lyrics-table").text.strip().split("\n");
#       5     tds = tbl.find_all("td", attrs={"style":"text-align:right;"})
#       6     out["title"] = tds[0].text.strip();
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [raw]
#  Hey, check it out! An error! It looks like we're having trouble with "Greek Number Three" which I happen to know is in Greek, rather than english. It probably doesn't have a Lyrics section. There are probably other songs without lyrics. Let's use exception handling to ignore and report on these sorts of things.

# %%
def scrape_tmbg_lyrics(discog_url):
    albums = get_album_list(discog_url);
    output = [];
    for album in albums:
        url = album['url'];
        tracks = scrape_lyrics_pages(url);
        for track in tracks:
            try:
                data = get_song_data(track);
                data['album'] = album['title'];
                output.append(data);
            except Exception as e:
                print("Ran into an error on {} ({})".format( track, e))
    return output;

# %%
verbose = True
scrape_tmbg_lyrics("http://tmbw.net/wiki/Discography")[0:10]
# Out:
# Cache hit: http://tmbw.net/wiki/Discography
# Cache hit: http://tmbw.net/wiki/Wiggle_Diskette
# Cache hit: http://tmbw.net/wiki/Lyrics:Everything_Right_Is_Wrong
# Cache hit: http://tmbw.net/wiki/Lyrics:You%27ll_Miss_Me_(Demo_1)
# Cache hit: http://tmbw.net/wiki/1985_Demo_Tape
# Cache hit: http://tmbw.net/wiki/Lyrics:Put_Your_Hand_Inside_The_Puppet_Head_(Demo_3)
# Cache hit: http://tmbw.net/wiki/Lyrics:When_It_Rains_It_Snows_(Demo)
# Cache hit: http://tmbw.net/wiki/Lyrics:Number_Three_(1985_Demo)
# Cache hit: http://tmbw.net/wiki/Lyrics:Don%27t_Let%27s_Start_(1985_Demo)
# Cache hit: http://tmbw.net/wiki/Lyrics:You%27ll_Miss_Me_(Demo_2)
# Cache hit: http://tmbw.net/wiki/Lyrics:I_Hope_That_I_Get_Old_Before_I_Die_(Demo)
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Biggest_One_(1985_Demo)
# Cache hit: http://tmbw.net/wiki/Lyrics:32_Footsteps
# Cache hit: http://tmbw.net/wiki/Lyrics:Boat_Of_Car_(1985_Demo)
# Cache hit: http://tmbw.net/wiki/Lyrics:Cowtown_(1985_Demo_2)
# Cache hit: http://tmbw.net/wiki/Lyrics:Chess_Piece_Face_(1985_Demo)
# Cache hit: http://tmbw.net/wiki/Lyrics:Rabid_Child
# Cache hit: http://tmbw.net/wiki/Lyrics:Youth_Culture_Killed_My_Dog_(1985_Demo)
# Cache hit: http://tmbw.net/wiki/Lyrics:Alienation%27s_For_The_Rich
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Day_(Demo)
# Cache hit: http://tmbw.net/wiki/Lyrics:(She_Was_A)_Hotel_Detective_(1985_Demo)
# Cache hit: http://tmbw.net/wiki/Lyrics:Which_Describes_How_You%27re_Feeling_(Demo)
# Cache hit: http://tmbw.net/wiki/Lyrics:Toddler_Hiway
# Cache hit: http://tmbw.net/wiki/Lyrics:Become_A_Robot
# Cache hit: http://tmbw.net/wiki/Lyrics:I%27m_Def
# Cache hit: http://tmbw.net/wiki/Lyrics:Hell_Hotel
# Cache hit: http://tmbw.net/wiki/Lyrics:They_Might_Be_Giants_(Song)_(1985_Demo)
# Cache hit: http://tmbw.net/wiki/Lyrics:Nothing%27s_Going_To_Change_My_Clothes
# Cache hit: http://tmbw.net/wiki/They_Might_Be_Giants_-_Joshua_Fried_Split_Single
# Cache hit: http://tmbw.net/wiki/Lyrics:Put_Your_Hand_Inside_The_Puppet_Head_(Demo_3)
# Cache hit: http://tmbw.net/wiki/Lyrics:Number_Three_(1985_Demo)
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Day_(Demo)
# Cache hit: http://tmbw.net/wiki/They_Might_Be_Giants_(Album)
# Cache hit: http://tmbw.net/wiki/Lyrics:Everything_Right_Is_Wrong_Again
# Cache hit: http://tmbw.net/wiki/Lyrics:Put_Your_Hand_Inside_The_Puppet_Head
# Cache hit: http://tmbw.net/wiki/Lyrics:Number_Three
# Cache hit: http://tmbw.net/wiki/Lyrics:Don%27t_Let%27s_Start
# Cache hit: http://tmbw.net/wiki/Lyrics:Hide_Away_Folk_Family
# Cache hit: http://tmbw.net/wiki/Lyrics:32_Footsteps
# Cache hit: http://tmbw.net/wiki/Lyrics:Toddler_Hiway
# Cache hit: http://tmbw.net/wiki/Lyrics:Rabid_Child
# Cache hit: http://tmbw.net/wiki/Lyrics:Nothing%27s_Gonna_Change_My_Clothes
# Cache hit: http://tmbw.net/wiki/Lyrics:(She_Was_A)_Hotel_Detective
# Cache hit: http://tmbw.net/wiki/Lyrics:She%27s_An_Angel
# Cache hit: http://tmbw.net/wiki/Lyrics:Youth_Culture_Killed_My_Dog
# Cache hit: http://tmbw.net/wiki/Lyrics:Boat_Of_Car
# Cache hit: http://tmbw.net/wiki/Lyrics:Absolutely_Bill%27s_Mood
# Cache hit: http://tmbw.net/wiki/Lyrics:Chess_Piece_Face
# Cache hit: http://tmbw.net/wiki/Lyrics:I_Hope_That_I_Get_Old_Before_I_Die
# Cache hit: http://tmbw.net/wiki/Lyrics:Alienation%27s_For_The_Rich
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Day
# Cache hit: http://tmbw.net/wiki/Lyrics:Rhythm_Section_Want_Ad
# Cache hit: http://tmbw.net/wiki/Lyrics:Don%27t_Let%27s_Start_(Single_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:We%27re_The_Replacements
# Cache hit: http://tmbw.net/wiki/Lyrics:When_It_Rains_It_Snows
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Famous_Polka
# Cache hit: http://tmbw.net/wiki/Lyrics:(She_Was_A)_Hotel_Detective_(Single_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:For_Science
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Biggest_One
# Cache hit: http://tmbw.net/wiki/Lyrics:Kiss_Me,_Son_Of_God_(Alternate_Version)
# Cache hit: http://tmbw.net/wiki/Lyrics:Mr._Klaw
# Cache hit: http://tmbw.net/wiki/Lyrics:Critic_Intro
# Cache hit: http://tmbw.net/wiki/Lyrics:Now_That_I_Have_Everything
# Cache hit: http://tmbw.net/wiki/Lyrics:Mainstream_U.S.A.
# Cache hit: http://tmbw.net/wiki/Lyrics:Fake_Out_In_Buenos_Aires
# Cache hit: http://tmbw.net/wiki/Lyrics:Greek_Number_Three
# Ran into an error on http://tmbw.net/wiki/Lyrics:Greek_Number_Three ('NoneType' object has no attribute 'text')
# Cache hit: http://tmbw.net/wiki/Lyrics:I_Hope_That_I_Get_Old_Before_I_Die_(Demo)
# Cache miss: http://tmbw.net/wiki/Lyrics:I%27m_Def_(Edit)
# Cache hit: http://tmbw.net/wiki/Lyrics:Don%27t_Let%27s_Start_(1985_Demo)
# Cache miss: http://tmbw.net/wiki/Lyrics:%2785_Radio_Special_Thank_You
# Cache miss: http://tmbw.net/wiki/Lyrics:Untitled
# Cache miss: http://tmbw.net/wiki/Don%27t_Let%27s_Start_(EP)
# Cache hit: http://tmbw.net/wiki/Lyrics:Don%27t_Let%27s_Start_(Single_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:We%27re_The_Replacements
# Cache hit: http://tmbw.net/wiki/Lyrics:When_It_Rains_It_Snows
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Famous_Polka
# Cache hit: http://tmbw.net/wiki/Lyrics:Don%27t_Let%27s_Start_(Single_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:We%27re_The_Replacements
# Cache hit: http://tmbw.net/wiki/Lyrics:Don%27t_Let%27s_Start_(Single_Mix)
# Cache miss: http://tmbw.net/wiki/Lyrics:Your_Racist_Friend_(Sampladelic_Remix)
# Cache hit: http://tmbw.net/wiki/Lyrics:She%27s_An_Angel
# Cache hit: http://tmbw.net/wiki/Lyrics:Absolutely_Bill%27s_Mood
# Cache hit: http://tmbw.net/wiki/Lyrics:Don%27t_Let%27s_Start_(Single_Mix)
# Cache miss: http://tmbw.net/wiki/Lyrics:Letterbox
# Cache miss: http://tmbw.net/wiki/Lyrics:Sapphire_Bullets_Of_Pure_Love
# Cache hit: http://tmbw.net/wiki/Lyrics:Don%27t_Let%27s_Start_(Single_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:Your_Racist_Friend_(Sampladelic_Remix)
# Cache miss: http://tmbw.net/wiki/Lyrics:Istanbul_(Not_Constantinople)_(Brownsville_Mix)
# Cache miss: http://tmbw.net/wiki/(She_Was_A)_Hotel_Detective_(EP)
# Cache hit: http://tmbw.net/wiki/Lyrics:(She_Was_A)_Hotel_Detective_(Single_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:Kiss_Me,_Son_Of_God_(Alternate_Version)
# Cache hit: http://tmbw.net/wiki/Lyrics:For_Science
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Biggest_One
# Cache hit: http://tmbw.net/wiki/Lyrics:Mr._Klaw
# Cache hit: http://tmbw.net/wiki/Lyrics:Untitled
# Cache hit: http://tmbw.net/wiki/Lyrics:(She_Was_A)_Hotel_Detective_(Single_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:Untitled
# Cache hit: http://tmbw.net/wiki/Lyrics:For_Science
# Cache hit: http://tmbw.net/wiki/Lyrics:Kiss_Me,_Son_Of_God_(Alternate_Version)
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Biggest_One
# Cache hit: http://tmbw.net/wiki/Lyrics:Mr._Klaw
# Cache hit: http://tmbw.net/wiki/Lyrics:(She_Was_A)_Hotel_Detective_(Single_Mix)
# Cache miss: http://tmbw.net/wiki/Lincoln
# Cache miss: http://tmbw.net/wiki/Lyrics:Ana_Ng
# Cache miss: http://tmbw.net/wiki/Lyrics:Cowtown
# Cache miss: http://tmbw.net/wiki/Lyrics:Lie_Still,_Little_Bottle
# Cache miss: http://tmbw.net/wiki/Lyrics:Purple_Toupee
# Cache miss: http://tmbw.net/wiki/Lyrics:Cage_%26_Aquarium
# Cache miss: http://tmbw.net/wiki/Lyrics:Where_Your_Eyes_Don%27t_Go
# Cache miss: http://tmbw.net/wiki/Lyrics:Piece_Of_Dirt
# Cache miss: http://tmbw.net/wiki/Lyrics:Mr._Me
# Cache miss: http://tmbw.net/wiki/Lyrics:Pencil_Rain
# Cache miss: http://tmbw.net/wiki/Lyrics:The_World%27s_Address
# Cache miss: http://tmbw.net/wiki/Lyrics:I%27ve_Got_A_Match
# Cache miss: http://tmbw.net/wiki/Lyrics:Santa%27s_Beard
# Cache miss: http://tmbw.net/wiki/Lyrics:You%27ll_Miss_Me
# Cache miss: http://tmbw.net/wiki/Lyrics:They%27ll_Need_A_Crane
# Cache miss: http://tmbw.net/wiki/Lyrics:Shoehorn_With_Teeth
# Cache miss: http://tmbw.net/wiki/Lyrics:Stand_On_Your_Own_Head
# Cache miss: http://tmbw.net/wiki/Lyrics:Snowball_In_Hell
# Cache miss: http://tmbw.net/wiki/Lyrics:Kiss_Me,_Son_Of_God
# Cache miss: http://tmbw.net/wiki/Lyrics:It%27s_Not_My_Birthday
# Cache miss: http://tmbw.net/wiki/Lyrics:I%27ll_Sink_Manhattan
# Cache miss: http://tmbw.net/wiki/Lyrics:Nightgown_Of_The_Sullen_Moon
# Cache miss: http://tmbw.net/wiki/Lyrics:Hey,_Mr._DJ,_I_Thought_You_Said_We_Had_A_Deal
# Cache miss: http://tmbw.net/wiki/Lyrics:Lady_Is_A_Tramp
# Cache miss: http://tmbw.net/wiki/Lyrics:Birds_Fly
# Cache miss: http://tmbw.net/wiki/Lyrics:Hello_Radio
# Cache miss: http://tmbw.net/wiki/Lyrics:The_World%27s_Address_(Joshua_Fried_Remix)
# Cache miss: http://tmbw.net/wiki/Lyrics:Kitten_Intro
# Cache miss: http://tmbw.net/wiki/Lyrics:Weep_Day
# Cache miss: http://tmbw.net/wiki/Lyrics:The_Big_Big_Whoredom
# Cache miss: http://tmbw.net/wiki/Lyrics:I%27m_Gettin%27_Sentimental_Over_You
# Cache hit: http://tmbw.net/wiki/Lyrics:Become_A_Robot
# Cache miss: http://tmbw.net/wiki/Lyrics:Which_Describes_How_You%27re_Feeling
# Cache miss: http://tmbw.net/wiki/Lyrics:Swing_Is_A_Word
# Cache miss: http://tmbw.net/wiki/Lyrics:Doris_Cunningham
# Cache miss: http://tmbw.net/wiki/Lyrics:Counterfeit_Fake
# Cache miss: http://tmbw.net/wiki/Lyrics:Schoolchildren_Singing_Particle_Man
# Cache miss: http://tmbw.net/wiki/Ana_Ng_(Single)
# Cache hit: http://tmbw.net/wiki/Lyrics:Ana_Ng
# Cache hit: http://tmbw.net/wiki/Lyrics:Ana_Ng
# Cache hit: http://tmbw.net/wiki/Lyrics:Nightgown_Of_The_Sullen_Moon
# Cache hit: http://tmbw.net/wiki/Lyrics:It%27s_Not_My_Birthday
# Cache hit: http://tmbw.net/wiki/Lyrics:Lie_Still,_Little_Bottle
# Cache hit: http://tmbw.net/wiki/Lyrics:Ana_Ng
# Cache hit: http://tmbw.net/wiki/Lyrics:Nightgown_Of_The_Sullen_Moon
# Cache hit: http://tmbw.net/wiki/Lyrics:Ana_Ng
# Cache hit: http://tmbw.net/wiki/Lyrics:Snowball_In_Hell
# Cache hit: http://tmbw.net/wiki/Lyrics:Ana_Ng
# Cache hit: http://tmbw.net/wiki/Lyrics:They%27ll_Need_A_Crane
# Cache hit: http://tmbw.net/wiki/Lyrics:(She_Was_A)_Hotel_Detective_(Single_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:Don%27t_Let%27s_Start_(Single_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:Ana_Ng
# Cache hit: http://tmbw.net/wiki/Lyrics:(She_Was_A)_Hotel_Detective_(Single_Mix)
# Cache miss: http://tmbw.net/wiki/They%27ll_Need_A_Crane_(EP)
# Cache hit: http://tmbw.net/wiki/Lyrics:They%27ll_Need_A_Crane
# Cache hit: http://tmbw.net/wiki/Lyrics:It%27s_Not_My_Birthday
# Cache hit: http://tmbw.net/wiki/Lyrics:I%27ll_Sink_Manhattan
# Cache hit: http://tmbw.net/wiki/Lyrics:Nightgown_Of_The_Sullen_Moon
# Cache hit: http://tmbw.net/wiki/Lyrics:They%27ll_Need_A_Crane
# Cache hit: http://tmbw.net/wiki/Lyrics:I%27ve_Got_A_Match
# Cache hit: http://tmbw.net/wiki/Lyrics:Kiss_Me,_Son_Of_God
# Cache hit: http://tmbw.net/wiki/Lyrics:I%27ll_Sink_Manhattan
# Cache hit: http://tmbw.net/wiki/Lyrics:They%27ll_Need_A_Crane
# Cache hit: http://tmbw.net/wiki/Lyrics:I%27ve_Got_A_Match
# Cache hit: http://tmbw.net/wiki/Lyrics:They%27ll_Need_A_Crane
# Cache hit: http://tmbw.net/wiki/Lyrics:It%27s_Not_My_Birthday
# Cache hit: http://tmbw.net/wiki/Lyrics:They%27ll_Need_A_Crane
# Cache hit: http://tmbw.net/wiki/Lyrics:They%27ll_Need_A_Crane
# Cache miss: http://tmbw.net/wiki/Don%27t_Let%27s_Start_(Album)
# Cache hit: http://tmbw.net/wiki/Lyrics:Don%27t_Let%27s_Start_(Single_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:Hey,_Mr._DJ,_I_Thought_You_Said_We_Had_A_Deal
# Cache hit: http://tmbw.net/wiki/Lyrics:Lady_Is_A_Tramp
# Cache hit: http://tmbw.net/wiki/Lyrics:Birds_Fly
# Cache hit: http://tmbw.net/wiki/Lyrics:The_World%27s_Address_(Joshua_Fried_Remix)
# Cache hit: http://tmbw.net/wiki/Lyrics:Nightgown_Of_The_Sullen_Moon
# Cache hit: http://tmbw.net/wiki/Lyrics:I%27ll_Sink_Manhattan
# Cache hit: http://tmbw.net/wiki/Lyrics:It%27s_Not_My_Birthday
# Cache hit: http://tmbw.net/wiki/Lyrics:Mr._Klaw
# Cache hit: http://tmbw.net/wiki/Lyrics:Kiss_Me,_Son_Of_God_(Alternate_Version)
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Biggest_One
# Cache hit: http://tmbw.net/wiki/Lyrics:For_Science
# Cache hit: http://tmbw.net/wiki/Lyrics:Untitled
# Cache hit: http://tmbw.net/wiki/Lyrics:(She_Was_A)_Hotel_Detective_(Single_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Famous_Polka
# Cache hit: http://tmbw.net/wiki/Lyrics:When_It_Rains_It_Snows
# Cache hit: http://tmbw.net/wiki/Lyrics:We%27re_The_Replacements
# Cache miss: http://tmbw.net/wiki/Birdhouse_In_Your_Soul_(EP)
# Cache miss: http://tmbw.net/wiki/Lyrics:Birdhouse_In_Your_Soul
# Cache miss: http://tmbw.net/wiki/Lyrics:Hot_Cha
# Cache miss: http://tmbw.net/wiki/Lyrics:Hearing_Aid
# Cache miss: http://tmbw.net/wiki/Lyrics:Ant
# Cache hit: http://tmbw.net/wiki/Lyrics:Birdhouse_In_Your_Soul
# Cache hit: http://tmbw.net/wiki/Lyrics:Hot_Cha
# Cache hit: http://tmbw.net/wiki/Lyrics:Birdhouse_In_Your_Soul
# Cache hit: http://tmbw.net/wiki/Lyrics:Hot_Cha
# Cache hit: http://tmbw.net/wiki/Lyrics:Hearing_Aid
# Cache miss: http://tmbw.net/wiki/Lyrics:Minimum_Wage
# Cache hit: http://tmbw.net/wiki/Lyrics:Ant
# Cache hit: http://tmbw.net/wiki/Lyrics:Birdhouse_In_Your_Soul
# Cache miss: http://tmbw.net/wiki/The_Videos_1986-1989
# Cache hit: http://tmbw.net/wiki/Lyrics:Purple_Toupee
# Cache hit: http://tmbw.net/wiki/Lyrics:They%27ll_Need_A_Crane
# Cache hit: http://tmbw.net/wiki/Lyrics:Ana_Ng
# Cache hit: http://tmbw.net/wiki/Lyrics:(She_Was_A)_Hotel_Detective_(Single_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:Don%27t_Let%27s_Start_(Single_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:Put_Your_Hand_Inside_The_Puppet_Head
# Cache miss: http://tmbw.net/wiki/Flood
# Cache miss: http://tmbw.net/wiki/Lyrics:Theme_From_Flood
# Cache hit: http://tmbw.net/wiki/Lyrics:Birdhouse_In_Your_Soul
# Cache miss: http://tmbw.net/wiki/Lyrics:Lucky_Ball_%26_Chain
# Cache miss: http://tmbw.net/wiki/Lyrics:Istanbul_(Not_Constantinople)
# Cache miss: http://tmbw.net/wiki/Lyrics:Dead
# Cache miss: http://tmbw.net/wiki/Lyrics:Your_Racist_Friend
# Cache miss: http://tmbw.net/wiki/Lyrics:Particle_Man
# Cache miss: http://tmbw.net/wiki/Lyrics:Twisting
# Cache miss: http://tmbw.net/wiki/Lyrics:We_Want_A_Rock
# Cache miss: http://tmbw.net/wiki/Lyrics:Someone_Keeps_Moving_My_Chair
# Cache hit: http://tmbw.net/wiki/Lyrics:Hearing_Aid
# Cache hit: http://tmbw.net/wiki/Lyrics:Minimum_Wage
# Cache hit: http://tmbw.net/wiki/Lyrics:Letterbox
# Cache miss: http://tmbw.net/wiki/Lyrics:Whistling_In_The_Dark
# Cache hit: http://tmbw.net/wiki/Lyrics:Hot_Cha
# Cache miss: http://tmbw.net/wiki/Lyrics:Women_%26_Men
# Cache hit: http://tmbw.net/wiki/Lyrics:Sapphire_Bullets_Of_Pure_Love
# Cache miss: http://tmbw.net/wiki/Lyrics:They_Might_Be_Giants_(Song)
# Cache miss: http://tmbw.net/wiki/Lyrics:Road_Movie_To_Berlin
# Cache miss: http://tmbw.net/wiki/Istanbul_(Not_Constantinople)_(EP)
# Cache hit: http://tmbw.net/wiki/Lyrics:Istanbul_(Not_Constantinople)
# Cache miss: http://tmbw.net/wiki/Lyrics:James_K._Polk_(Original_Version)
# Cache miss: http://tmbw.net/wiki/Lyrics:Stormy_Pinkness
# Cache hit: http://tmbw.net/wiki/Lyrics:Ant
# Cache hit: http://tmbw.net/wiki/Lyrics:Istanbul_(Not_Constantinople)_(Brownsville_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:Istanbul_(Not_Constantinople)
# Cache hit: http://tmbw.net/wiki/Lyrics:Istanbul_(Not_Constantinople)_(Brownsville_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:Istanbul_(Not_Constantinople)
# Cache hit: http://tmbw.net/wiki/Lyrics:James_K._Polk_(Original_Version)
# Cache hit: http://tmbw.net/wiki/Lyrics:Stormy_Pinkness
# Cache hit: http://tmbw.net/wiki/Lyrics:Istanbul_(Not_Constantinople)_(Brownsville_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:Istanbul_(Not_Constantinople)
# Cache hit: http://tmbw.net/wiki/Lyrics:James_K._Polk_(Original_Version)
# Cache hit: http://tmbw.net/wiki/Lyrics:Istanbul_(Not_Constantinople)
# Cache hit: http://tmbw.net/wiki/Lyrics:Istanbul_(Not_Constantinople)_(Brownsville_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:Istanbul_(Not_Constantinople)_(Brownsville_Mix)
# Cache miss: http://tmbw.net/wiki/Lyrics:Istanbul_(Not_Constantinople)_(Bedford/Stuyvesant_Mix)
# Cache miss: http://tmbw.net/wiki/Lyrics:Istanbul_(Not_Constantinople)_(Park_Slope_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:Istanbul_(Not_Constantinople)
# Cache hit: http://tmbw.net/wiki/Lyrics:Istanbul_(Not_Constantinople)
# Cache miss: http://tmbw.net/wiki/Miscellaneous_T
# Cache hit: http://tmbw.net/wiki/Lyrics:Hey,_Mr._DJ,_I_Thought_You_Said_We_Had_A_Deal
# Cache hit: http://tmbw.net/wiki/Lyrics:Lady_Is_A_Tramp
# Cache hit: http://tmbw.net/wiki/Lyrics:Birds_Fly
# Cache hit: http://tmbw.net/wiki/Lyrics:The_World%27s_Address_(Joshua_Fried_Remix)
# Cache hit: http://tmbw.net/wiki/Lyrics:Nightgown_Of_The_Sullen_Moon
# Cache hit: http://tmbw.net/wiki/Lyrics:I%27ll_Sink_Manhattan
# Cache hit: http://tmbw.net/wiki/Lyrics:It%27s_Not_My_Birthday
# Cache hit: http://tmbw.net/wiki/Lyrics:Hello_Radio
# Cache hit: http://tmbw.net/wiki/Lyrics:Mr._Klaw
# Cache hit: http://tmbw.net/wiki/Lyrics:Kiss_Me,_Son_Of_God_(Alternate_Version)
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Biggest_One
# Cache hit: http://tmbw.net/wiki/Lyrics:For_Science
# Cache hit: http://tmbw.net/wiki/Lyrics:Untitled
# Cache hit: http://tmbw.net/wiki/Lyrics:(She_Was_A)_Hotel_Detective_(Single_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Famous_Polka
# Cache hit: http://tmbw.net/wiki/Lyrics:When_It_Rains_It_Snows
# Cache hit: http://tmbw.net/wiki/Lyrics:We%27re_The_Replacements
# Cache hit: http://tmbw.net/wiki/Lyrics:Don%27t_Let%27s_Start_(Single_Mix)
# Cache miss: http://tmbw.net/wiki/Video_Compilation
# Cache hit: http://tmbw.net/wiki/Lyrics:Put_Your_Hand_Inside_The_Puppet_Head
# Cache hit: http://tmbw.net/wiki/Lyrics:Don%27t_Let%27s_Start_(Single_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:(She_Was_A)_Hotel_Detective_(Single_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:Ana_Ng
# Cache hit: http://tmbw.net/wiki/Lyrics:They%27ll_Need_A_Crane
# Cache hit: http://tmbw.net/wiki/Lyrics:Purple_Toupee
# Cache hit: http://tmbw.net/wiki/Lyrics:Put_Your_Hand_Inside_The_Puppet_Head
# Cache hit: http://tmbw.net/wiki/Lyrics:Don%27t_Let%27s_Start_(Single_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:(She_Was_A)_Hotel_Detective_(Single_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:Ana_Ng
# Cache hit: http://tmbw.net/wiki/Lyrics:They%27ll_Need_A_Crane
# Cache hit: http://tmbw.net/wiki/Lyrics:Purple_Toupee
# Cache hit: http://tmbw.net/wiki/Lyrics:Birdhouse_In_Your_Soul
# Cache hit: http://tmbw.net/wiki/Lyrics:Istanbul_(Not_Constantinople)
# Cache miss: http://tmbw.net/wiki/The_Statue_Got_Me_High_(EP)
# Cache miss: http://tmbw.net/wiki/Lyrics:The_Statue_Got_Me_High
# Cache miss: http://tmbw.net/wiki/Lyrics:She%27s_Actual_Size
# Cache hit: http://tmbw.net/wiki/Lyrics:I%27m_Def_(Edit)
# Cache hit: http://tmbw.net/wiki/Lyrics:Which_Describes_How_You%27re_Feeling_(Demo)
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Statue_Got_Me_High
# Cache hit: http://tmbw.net/wiki/Lyrics:She%27s_Actual_Size
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Statue_Got_Me_High
# Cache hit: http://tmbw.net/wiki/Lyrics:Which_Describes_How_You%27re_Feeling_(Demo)
# Cache hit: http://tmbw.net/wiki/Lyrics:I%27m_Def_(Edit)
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Statue_Got_Me_High
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Statue_Got_Me_High
# Cache hit: http://tmbw.net/wiki/Apollo_18
# Cache miss: http://tmbw.net/wiki/Lyrics:Dig_My_Grave
# Cache miss: http://tmbw.net/wiki/Lyrics:I_Palindrome_I
# Cache hit: http://tmbw.net/wiki/Lyrics:She%27s_Actual_Size
# Cache miss: http://tmbw.net/wiki/Lyrics:My_Evil_Twin
# Cache miss: http://tmbw.net/wiki/Lyrics:Mammal
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Statue_Got_Me_High
# Cache miss: http://tmbw.net/wiki/Lyrics:Spider
# Cache miss: http://tmbw.net/wiki/Lyrics:The_Guitar
# Cache miss: http://tmbw.net/wiki/Lyrics:Dinner_Bell
# Cache miss: http://tmbw.net/wiki/Lyrics:Narrow_Your_Eyes
# Cache miss: http://tmbw.net/wiki/Lyrics:Hall_Of_Heads
# Cache hit: http://tmbw.net/wiki/Lyrics:Which_Describes_How_You%27re_Feeling
# Cache miss: http://tmbw.net/wiki/Lyrics:See_The_Constellation
# Cache miss: http://tmbw.net/wiki/Lyrics:If_I_Wasn%27t_Shy
# Cache miss: http://tmbw.net/wiki/Lyrics:Turn_Around
# Cache miss: http://tmbw.net/wiki/Lyrics:Hypnotist_Of_Ladies
# Cache miss: http://tmbw.net/wiki/Lyrics:Everything_Is_Catching_On_Fire
# Cache miss: http://tmbw.net/wiki/Lyrics:Fingertips_(Banjo)
# Cache miss: http://tmbw.net/wiki/Lyrics:I_Hear_The_Wind_Blow
# Cache miss: http://tmbw.net/wiki/Lyrics:Hey_Now_Everybody
# Cache miss: http://tmbw.net/wiki/Lyrics:Who%27s_That_Standing_Out_The_Window%3F
# Cache miss: http://tmbw.net/wiki/Lyrics:I_Found_A_New_Friend_Underneath_My_Pillow
# Cache miss: http://tmbw.net/wiki/Lyrics:Come_On_And_Wreck_My_Car
# Cache miss: http://tmbw.net/wiki/Lyrics:Aren%27t_You_The_Guy_Who_Hit_Me_In_The_Eye%3F
# Cache miss: http://tmbw.net/wiki/Lyrics:Please_Pass_The_Milk
# Cache miss: http://tmbw.net/wiki/Lyrics:Leave_Me_Alone
# Cache miss: http://tmbw.net/wiki/Lyrics:Who%27s_Knocking_On_The_Wall%3F
# Cache miss: http://tmbw.net/wiki/Lyrics:All_Alone,_All_By_Myself
# Cache miss: http://tmbw.net/wiki/Lyrics:What%27s_That_Blue_Thing_Doing_Here%3F
# Cache miss: http://tmbw.net/wiki/Lyrics:Something_Grabbed_Ahold_Of_My_Hand
# Cache miss: http://tmbw.net/wiki/Lyrics:I_Don%27t_Understand_You
# Cache miss: http://tmbw.net/wiki/Lyrics:I_Heard_A_Sound
# Cache miss: http://tmbw.net/wiki/Lyrics:Mysterious_Whisper
# Cache miss: http://tmbw.net/wiki/Lyrics:The_Day_That_Love_Came_To_Play
# Cache miss: http://tmbw.net/wiki/Lyrics:I%27m_Having_A_Heart_Attack
# Cache miss: http://tmbw.net/wiki/Lyrics:Fingertips_(Whispered)
# Cache miss: http://tmbw.net/wiki/Lyrics:I_Walk_Along_Darkened_Corridors
# Cache miss: http://tmbw.net/wiki/Lyrics:Space_Suit
# Cache miss: http://tmbw.net/wiki/I_Palindrome_I_(EP)
# Cache hit: http://tmbw.net/wiki/Lyrics:I_Palindrome_I
# Cache miss: http://tmbw.net/wiki/Lyrics:Cabbagetown
# Cache miss: http://tmbw.net/wiki/Lyrics:Siftin%27
# Cache miss: http://tmbw.net/wiki/Lyrics:Larger_Than_Life
# Cache hit: http://tmbw.net/wiki/Lyrics:I_Palindrome_I
# Cache hit: http://tmbw.net/wiki/Lyrics:Cabbagetown
# Cache hit: http://tmbw.net/wiki/Lyrics:I_Palindrome_I
# Cache miss: http://tmbw.net/wiki/The_Guitar_(The_Lion_Sleeps_Tonight)_(EP)
# Cache miss: http://tmbw.net/wiki/Lyrics:The_Guitar_(Williamsburgh_Mix)
# Cache miss: http://tmbw.net/wiki/Lyrics:The_Guitar_(Outer_Planet_Mix)
# Cache miss: http://tmbw.net/wiki/Lyrics:Welcome_To_The_Jungle
# Cache miss: http://tmbw.net/wiki/Lyrics:I_Blame_You
# Cache miss: http://tmbw.net/wiki/Lyrics:Moving_To_The_Sun
# Cache miss: http://tmbw.net/wiki/Lyrics:The_Guitar_(Even_Further_Outer_Planet_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Guitar
# Cache miss: http://tmbw.net/wiki/Lyrics:The_Guitar_(UK_Single_Edit)
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Guitar_(Williamsburgh_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:Cabbagetown
# Cache hit: http://tmbw.net/wiki/Lyrics:Siftin%27
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Guitar_(Williamsburgh_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:Larger_Than_Life
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Guitar_(Outer_Planet_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Guitar_(Even_Further_Outer_Planet_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Guitar_(Outer_Planet_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Guitar_(Even_Further_Outer_Planet_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Guitar_(Williamsburgh_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:Larger_Than_Life
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Guitar_(UK_Single_Edit)
# Cache miss: http://tmbw.net/wiki/Lyrics:The_Guitar_(Williamsburg_Mix)
# Cache miss: http://tmbw.net/wiki/Lyrics:The_Guitar_(The_Lion_Sleeps_Tonight)_(Even_Further_Outer_Planet_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Guitar_(Outer_Planet_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Guitar_(UK_Single_Edit)
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Guitar_(Williamsburgh_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Guitar_(Outer_Planet_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Guitar_(Even_Further_Outer_Planet_Mix)
# Cache miss: http://tmbw.net/wiki/Why_Does_The_Sun_Shine_(EP)
# Cache miss: http://tmbw.net/wiki/Lyrics:Why_Does_The_Sun_Shine%3F
# Cache miss: http://tmbw.net/wiki/Lyrics:Jessica
# Cache miss: http://tmbw.net/wiki/Lyrics:Whirlpool
# Cache miss: http://tmbw.net/wiki/Lyrics:Spy_(Original_Version)
# Cache hit: http://tmbw.net/wiki/Lyrics:Why_Does_The_Sun_Shine%3F
# Cache hit: http://tmbw.net/wiki/Lyrics:Jessica
# Cache miss: http://tmbw.net/wiki/O_Tannenbaum_(Single)
# Cache miss: http://tmbw.net/wiki/Lyrics:O_Tannenbaum
# Cache miss: http://tmbw.net/wiki/Lyrics:Christmas_Cards
# Cache miss: http://tmbw.net/wiki/Back_To_Skull
# Cache miss: http://tmbw.net/wiki/Lyrics:Snail_Shell
# Cache miss: http://tmbw.net/wiki/Lyrics:Ondine
# Cache miss: http://tmbw.net/wiki/Lyrics:She_Was_A_Hotel_Detective
# Cache miss: http://tmbw.net/wiki/Lyrics:Mrs._Train
# Cache miss: http://tmbw.net/wiki/Lyrics:Snail_Dust
# Cache hit: http://tmbw.net/wiki/Lyrics:Snail_Shell
# Cache hit: http://tmbw.net/wiki/Lyrics:She_Was_A_Hotel_Detective
# Cache hit: http://tmbw.net/wiki/Lyrics:Mrs._Train
# Cache hit: http://tmbw.net/wiki/Lyrics:Snail_Dust
# Cache miss: http://tmbw.net/wiki/John_Henry
# Cache miss: http://tmbw.net/wiki/Lyrics:Subliminal
# Cache hit: http://tmbw.net/wiki/Lyrics:Snail_Shell
# Cache miss: http://tmbw.net/wiki/Lyrics:Sleeping_In_The_Flowers
# Cache miss: http://tmbw.net/wiki/Lyrics:Unrelated_Thing
# Cache miss: http://tmbw.net/wiki/Lyrics:AKA_Driver
# Cache miss: http://tmbw.net/wiki/Lyrics:I_Should_Be_Allowed_To_Think
# Cache miss: http://tmbw.net/wiki/Lyrics:Extra_Savoir-Faire
# Cache miss: http://tmbw.net/wiki/Lyrics:Why_Must_I_Be_Sad%3F
# Cache miss: http://tmbw.net/wiki/Lyrics:Spy
# Cache miss: http://tmbw.net/wiki/Lyrics:O,_Do_Not_Forsake_Me
# Cache miss: http://tmbw.net/wiki/Lyrics:No_One_Knows_My_Plan
# Cache miss: http://tmbw.net/wiki/Lyrics:Dirt_Bike
# Cache miss: http://tmbw.net/wiki/Lyrics:Destination_Moon
# Cache hit: http://tmbw.net/wiki/Lyrics:A_Self_Called_Nowhere
# Cache miss: http://tmbw.net/wiki/Lyrics:Meet_James_Ensor
# Cache miss: http://tmbw.net/wiki/Lyrics:Thermostat
# Cache hit: http://tmbw.net/wiki/Lyrics:Window
# Cache miss: http://tmbw.net/wiki/Lyrics:Out_Of_Jail
# Cache miss: http://tmbw.net/wiki/Lyrics:Stomp_Box
# Cache miss: http://tmbw.net/wiki/Lyrics:The_End_Of_The_Tour
# Cache miss: http://tmbw.net/wiki/Live!!_New_York_City_10/14/94
# Cache miss: http://tmbw.net/wiki/Lyrics:O,_Do_Not_Forsake_Me_(Live_NYC)
# Cache miss: http://tmbw.net/wiki/Lyrics:Don%27t_Let%27s_Start_(Live_NYC)
# Cache miss: http://tmbw.net/wiki/Lyrics:AKA_Driver_(Live_NYC)
# Cache miss: http://tmbw.net/wiki/Lyrics:Why_Does_The_Sun_Shine%3F_(Live_NYC)
# Cache miss: http://tmbw.net/wiki/Lyrics:Purple_Toupee_(Live_NYC)
# Cache miss: http://tmbw.net/wiki/Lyrics:Sleeping_In_The_Flowers_(Live_NYC)
# Cache miss: http://tmbw.net/wiki/Lyrics:Chess_Piece_Face_(Live_NYC)
# Cache miss: http://tmbw.net/wiki/Lyrics:Particle_Man_(Live_NYC)
# Cache miss: http://tmbw.net/wiki/Lyrics:She%27s_An_Angel_(Live_NYC)
# Cache miss: http://tmbw.net/wiki/Lyrics:The_Statue_Got_Me_High_(Live_NYC)
# Cache miss: http://tmbw.net/wiki/Lyrics:Whistling_In_The_Dark_(Live_NYC)
# Cache miss: http://tmbw.net/wiki/Lyrics:Ana_Ng_(Live_NYC)
# Cache miss: http://tmbw.net/wiki/Lyrics:Turn_Around_(Live_NYC)
# Cache miss: http://tmbw.net/wiki/Lyrics:I_Palindrome_I_(Live_NYC)
# Cache miss: http://tmbw.net/wiki/Lyrics:Birdhouse_In_Your_Soul_(Live_NYC)
# Cache miss: http://tmbw.net/wiki/Lyrics:Snail_Shell_(Live_NYC)
# Cache miss: http://tmbw.net/wiki/Lyrics:Twisting_(Live_NYC)
# Cache miss: http://tmbw.net/wiki/Lyrics:Dig_My_Grave_(Live_NYC)
# Cache miss: http://tmbw.net/wiki/New_York_City_Live!!
# Cache hit: http://tmbw.net/wiki/Lyrics:Don%27t_Let%27s_Start_(Live_NYC)
# Cache miss: http://tmbw.net/wiki/Lyrics:Ana_Ng_(Alternate_Version)
# Cache hit: http://tmbw.net/wiki/Lyrics:Particle_Man_(Live_NYC)
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Statue_Got_Me_High_(Live_NYC)
# Cache hit: http://tmbw.net/wiki/Lyrics:Birdhouse_In_Your_Soul_(Live_NYC)
# Cache hit: http://tmbw.net/wiki/Lyrics:Twisting_(Live_NYC)
# Cache miss: http://tmbw.net/wiki/Factory_Showroom
# Cache miss: http://tmbw.net/wiki/Lyrics:Token_Back_To_Brooklyn
# Cache miss: http://tmbw.net/wiki/Lyrics:S-E-X-X-Y
# Cache miss: http://tmbw.net/wiki/Lyrics:Till_My_Head_Falls_Off
# Cache miss: http://tmbw.net/wiki/Lyrics:How_Can_I_Sing_Like_A_Girl%3F
# Cache miss: http://tmbw.net/wiki/Lyrics:Exquisite_Dead_Guy
# Cache miss: http://tmbw.net/wiki/Lyrics:Metal_Detector
# Cache miss: http://tmbw.net/wiki/Lyrics:New_York_City
# Cache miss: http://tmbw.net/wiki/Lyrics:Your_Own_Worst_Enemy
# Cache miss: http://tmbw.net/wiki/Lyrics:XTC_Vs._Adam_Ant
# Cache miss: http://tmbw.net/wiki/Lyrics:Spiraling_Shape
# Cache miss: http://tmbw.net/wiki/Lyrics:James_K._Polk
# Cache miss: http://tmbw.net/wiki/Lyrics:Pet_Name
# Cache miss: http://tmbw.net/wiki/Lyrics:I_Can_Hear_You
# Cache miss: http://tmbw.net/wiki/Lyrics:The_Bells_Are_Ringing
# Cache miss: http://tmbw.net/wiki/Lyrics:Unforgotten
# Cache miss: http://tmbw.net/wiki/Lyrics:Sensurround
# Cache miss: http://tmbw.net/wiki/S-E-X-X-Y_(EP)
# Cache miss: http://tmbw.net/wiki/Lyrics:S-E-X-X-Y_(Radio_Edit)
# Cache hit: http://tmbw.net/wiki/Lyrics:Sensurround
# Cache hit: http://tmbw.net/wiki/Lyrics:Unforgotten
# Cache miss: http://tmbw.net/wiki/Lyrics:We%27ve_Got_A_World_That_Swings
# Cache miss: http://tmbw.net/wiki/Lyrics:S-E-X-X-Y_(Warren_Rigg_Microwave_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:S-E-X-X-Y_(Radio_Edit)
# Cache hit: http://tmbw.net/wiki/Lyrics:We%27ve_Got_A_World_That_Swings
# Cache hit: http://tmbw.net/wiki/Lyrics:S-E-X-X-Y_(Warren_Rigg_Microwave_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:S-E-X-X-Y_(Radio_Edit)
# Cache hit: http://tmbw.net/wiki/Lyrics:S-E-X-X-Y_(Warren_Rigg_Microwave_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:S-E-X-X-Y_(Radio_Edit)
# Cache miss: http://tmbw.net/wiki/Lyrics:S-E-X-X-Y_(Tee%27s_Radio_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:S-E-X-X-Y_(Warren_Rigg_Microwave_Mix)
# Cache miss: http://tmbw.net/wiki/Lyrics:S-E-X-X-Y_(Tee%27s_Freeze_Mix)
# Cache miss: http://tmbw.net/wiki/Lyrics:S-E-X-X-Y_(Tee%27s_In_House_Dub)
# Cache miss: http://tmbw.net/wiki/Lyrics:S-E-X-X-Y_(Tee%27s_Cappella)
# Cache hit: http://tmbw.net/wiki/Lyrics:S-E-X-X-Y_(Warren_Rigg_Microwave_Mix)
# Cache miss: http://tmbw.net/wiki/Lyrics:S-E-X-X-Y_(Warren_Rigg_Instrumental_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:S-E-X-X-Y_(Radio_Edit)
# Cache hit: http://tmbw.net/wiki/Lyrics:Sensurround
# Cache hit: http://tmbw.net/wiki/Lyrics:Unforgotten
# Cache hit: http://tmbw.net/wiki/Lyrics:We%27ve_Got_A_World_That_Swings
# Cache hit: http://tmbw.net/wiki/Lyrics:S-E-X-X-Y_(Warren_Rigg_Microwave_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:S-E-X-X-Y_(Tee%27s_Freeze_Mix)
# Cache miss: http://tmbw.net/wiki/Then:_The_Earlier_Years
# Cache hit: http://tmbw.net/wiki/Lyrics:Everything_Right_Is_Wrong_Again
# Cache hit: http://tmbw.net/wiki/Lyrics:Put_Your_Hand_Inside_The_Puppet_Head
# Cache hit: http://tmbw.net/wiki/Lyrics:Number_Three
# Cache hit: http://tmbw.net/wiki/Lyrics:Don%27t_Let%27s_Start_(Single_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:Hide_Away_Folk_Family
# Cache hit: http://tmbw.net/wiki/Lyrics:32_Footsteps
# Cache hit: http://tmbw.net/wiki/Lyrics:Toddler_Hiway
# Cache hit: http://tmbw.net/wiki/Lyrics:Rabid_Child
# Cache hit: http://tmbw.net/wiki/Lyrics:Nothing%27s_Gonna_Change_My_Clothes
# Cache hit: http://tmbw.net/wiki/Lyrics:(She_Was_A)_Hotel_Detective
# Cache hit: http://tmbw.net/wiki/Lyrics:She%27s_An_Angel
# Cache hit: http://tmbw.net/wiki/Lyrics:Youth_Culture_Killed_My_Dog
# Cache hit: http://tmbw.net/wiki/Lyrics:Boat_Of_Car
# Cache hit: http://tmbw.net/wiki/Lyrics:Absolutely_Bill%27s_Mood
# Cache hit: http://tmbw.net/wiki/Lyrics:Chess_Piece_Face
# Cache hit: http://tmbw.net/wiki/Lyrics:I_Hope_That_I_Get_Old_Before_I_Die
# Cache hit: http://tmbw.net/wiki/Lyrics:Alienation%27s_For_The_Rich
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Day
# Cache hit: http://tmbw.net/wiki/Lyrics:Rhythm_Section_Want_Ad
# Cache hit: http://tmbw.net/wiki/Lyrics:We%27re_The_Replacements
# Cache hit: http://tmbw.net/wiki/Lyrics:When_It_Rains_It_Snows
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Famous_Polka
# Cache hit: http://tmbw.net/wiki/Lyrics:Untitled
# Cache hit: http://tmbw.net/wiki/Lyrics:For_Science
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Biggest_One
# Cache hit: http://tmbw.net/wiki/Lyrics:Kiss_Me,_Son_Of_God_(Alternate_Version)
# Cache hit: http://tmbw.net/wiki/Lyrics:Mr._Klaw
# Cache hit: http://tmbw.net/wiki/Lyrics:Critic_Intro
# Cache hit: http://tmbw.net/wiki/Lyrics:Now_That_I_Have_Everything
# Cache hit: http://tmbw.net/wiki/Lyrics:Mainstream_U.S.A.
# Cache hit: http://tmbw.net/wiki/Lyrics:Fake_Out_In_Buenos_Aires
# Cache hit: http://tmbw.net/wiki/Lyrics:Greek_Number_Three
# Ran into an error on http://tmbw.net/wiki/Lyrics:Greek_Number_Three ('NoneType' object has no attribute 'text')
# Cache hit: http://tmbw.net/wiki/Lyrics:I_Hope_That_I_Get_Old_Before_I_Die_(Demo)
# Cache hit: http://tmbw.net/wiki/Lyrics:I%27m_Def_(Edit)
# Cache hit: http://tmbw.net/wiki/Lyrics:Don%27t_Let%27s_Start_(1985_Demo)
# Cache hit: http://tmbw.net/wiki/Lyrics:%2785_Radio_Special_Thank_You
# Cache hit: http://tmbw.net/wiki/Lyrics:Ana_Ng
# Cache hit: http://tmbw.net/wiki/Lyrics:Cowtown
# Cache hit: http://tmbw.net/wiki/Lyrics:Lie_Still,_Little_Bottle
# Cache hit: http://tmbw.net/wiki/Lyrics:Purple_Toupee
# Cache hit: http://tmbw.net/wiki/Lyrics:Cage_%26_Aquarium
# Cache hit: http://tmbw.net/wiki/Lyrics:Where_Your_Eyes_Don%27t_Go
# Cache hit: http://tmbw.net/wiki/Lyrics:Piece_Of_Dirt
# Cache hit: http://tmbw.net/wiki/Lyrics:Mr._Me
# Cache hit: http://tmbw.net/wiki/Lyrics:Pencil_Rain
# Cache hit: http://tmbw.net/wiki/Lyrics:The_World%27s_Address
# Cache hit: http://tmbw.net/wiki/Lyrics:I%27ve_Got_A_Match
# Cache hit: http://tmbw.net/wiki/Lyrics:Santa%27s_Beard
# Cache hit: http://tmbw.net/wiki/Lyrics:You%27ll_Miss_Me
# Cache hit: http://tmbw.net/wiki/Lyrics:They%27ll_Need_A_Crane
# Cache hit: http://tmbw.net/wiki/Lyrics:Shoehorn_With_Teeth
# Cache hit: http://tmbw.net/wiki/Lyrics:Stand_On_Your_Own_Head
# Cache hit: http://tmbw.net/wiki/Lyrics:Snowball_In_Hell
# Cache hit: http://tmbw.net/wiki/Lyrics:Kiss_Me,_Son_Of_God
# Cache hit: http://tmbw.net/wiki/Lyrics:Hello_Radio
# Cache hit: http://tmbw.net/wiki/Lyrics:It%27s_Not_My_Birthday
# Cache hit: http://tmbw.net/wiki/Lyrics:I%27ll_Sink_Manhattan
# Cache hit: http://tmbw.net/wiki/Lyrics:Nightgown_Of_The_Sullen_Moon
# Cache hit: http://tmbw.net/wiki/Lyrics:The_World%27s_Address_(Joshua_Fried_Remix)
# Cache hit: http://tmbw.net/wiki/Lyrics:Hey,_Mr._DJ,_I_Thought_You_Said_We_Had_A_Deal
# Cache hit: http://tmbw.net/wiki/Lyrics:Lady_Is_A_Tramp
# Cache hit: http://tmbw.net/wiki/Lyrics:Birds_Fly
# Cache hit: http://tmbw.net/wiki/Lyrics:Kitten_Intro
# Cache hit: http://tmbw.net/wiki/Lyrics:Weep_Day
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Big_Big_Whoredom
# Cache hit: http://tmbw.net/wiki/Lyrics:I%27m_Gettin%27_Sentimental_Over_You
# Cache hit: http://tmbw.net/wiki/Lyrics:Become_A_Robot
# Cache hit: http://tmbw.net/wiki/Lyrics:Which_Describes_How_You%27re_Feeling_(Demo)
# Cache hit: http://tmbw.net/wiki/Lyrics:Swing_Is_A_Word
# Cache hit: http://tmbw.net/wiki/Lyrics:Doris_Cunningham
# Cache hit: http://tmbw.net/wiki/Lyrics:Counterfeit_Fake
# Cache hit: http://tmbw.net/wiki/Lyrics:Schoolchildren_Singing_Particle_Man
# Cache miss: http://tmbw.net/wiki/Severe_Tire_Damage
# Cache miss: http://tmbw.net/wiki/Lyrics:Doctor_Worm
# Cache miss: http://tmbw.net/wiki/Lyrics:Severe_Tire_Damage_Theme
# Cache miss: http://tmbw.net/wiki/Lyrics:They_Got_Lost_(Live_STD)
# Cache miss: http://tmbw.net/wiki/Lyrics:Why_Does_The_Sun_Shine%3F_(Live_STD)
# Cache miss: http://tmbw.net/wiki/Lyrics:Birdhouse_In_Your_Soul_(Live_STD)
# Cache miss: http://tmbw.net/wiki/Lyrics:She%27s_An_Angel_(Live_STD)
# Cache miss: http://tmbw.net/wiki/Lyrics:XTC_Vs._Adam_Ant_(Live_STD)
# Cache miss: http://tmbw.net/wiki/Lyrics:Istanbul_(Not_Constantinople)_(Live_STD)
# Cache miss: http://tmbw.net/wiki/Lyrics:Ana_Ng_(Live_STD)
# Cache miss: http://tmbw.net/wiki/Lyrics:First_Kiss
# Cache miss: http://tmbw.net/wiki/Lyrics:Spider_(Live_STD)
# Cache miss: http://tmbw.net/wiki/Lyrics:Particle_Man_(Live_STD)
# Cache miss: http://tmbw.net/wiki/Lyrics:She%27s_Actual_Size_(Live_STD)
# Cache miss: http://tmbw.net/wiki/Lyrics:S-E-X-X-Y_(Live_STD)
# Cache miss: http://tmbw.net/wiki/Lyrics:Meet_James_Ensor_(Live_STD)
# Cache miss: http://tmbw.net/wiki/Lyrics:Till_My_Head_Falls_Off_(Live_STD)
# Cache miss: http://tmbw.net/wiki/Lyrics:About_Me
# Cache miss: http://tmbw.net/wiki/Lyrics:Planet_Of_The_Apes
# Cache miss: http://tmbw.net/wiki/Lyrics:Return_To_The_Planet_Of_The_Apes
# Cache miss: http://tmbw.net/wiki/Lyrics:Conquest_Of_The_Planet_Of_The_Apes
# Cache miss: http://tmbw.net/wiki/Lyrics:Escape_From_The_Planet_Of_The_Apes
# Cache miss: http://tmbw.net/wiki/Lyrics:Battle_For_The_Planet_Of_The_Apes
# Cache miss: http://tmbw.net/wiki/Lyrics:Beneath_The_Planet_Of_The_Apes
# Cache miss: http://tmbw.net/wiki/Lyrics:This_Ape%27s_For_You
# Cache miss: http://tmbw.net/wiki/Doctor_Worm_(Single)
# Cache hit: http://tmbw.net/wiki/Lyrics:Doctor_Worm
# Cache hit: http://tmbw.net/wiki/Lyrics:Birdhouse_In_Your_Soul_(Live_STD)
# Cache hit: http://tmbw.net/wiki/Lyrics:Istanbul_(Not_Constantinople)_(Live_STD)
# Cache hit: http://tmbw.net/wiki/Lyrics:XTC_Vs._Adam_Ant_(Live_STD)
# Cache hit: http://tmbw.net/wiki/Lyrics:Doctor_Worm
# Cache miss: http://tmbw.net/wiki/Direct_From_Brooklyn
# Cache hit: http://tmbw.net/wiki/Lyrics:Doctor_Worm
# Cache hit: http://tmbw.net/wiki/Lyrics:Snail_Shell
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Guitar
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Statue_Got_Me_High
# Cache hit: http://tmbw.net/wiki/Lyrics:Istanbul_(Not_Constantinople)
# Cache hit: http://tmbw.net/wiki/Lyrics:Birdhouse_In_Your_Soul
# Cache hit: http://tmbw.net/wiki/Lyrics:They%27ll_Need_A_Crane
# Cache hit: http://tmbw.net/wiki/Lyrics:Purple_Toupee
# Cache hit: http://tmbw.net/wiki/Lyrics:Ana_Ng
# Cache hit: http://tmbw.net/wiki/Lyrics:(She_Was_A)_Hotel_Detective
# Cache hit: http://tmbw.net/wiki/Lyrics:Don%27t_Let%27s_Start
# Cache hit: http://tmbw.net/wiki/Lyrics:Put_Your_Hand_Inside_The_Puppet_Head
# Cache hit: http://tmbw.net/wiki/Lyrics:Particle_Man
# Cache hit: http://tmbw.net/wiki/Lyrics:Istanbul_(Not_Constantinople)
# Cache hit: http://tmbw.net/wiki/Lyrics:Why_Does_The_Sun_Shine%3F
# Cache miss: http://tmbw.net/wiki/Lyrics:All_MacGyver_On_It
# Cache miss: http://tmbw.net/wiki/Lyrics:Your_Mom%27s_Alright
# Cache miss: http://tmbw.net/wiki/Lyrics:Man,_It%27s_So_Loud_In_Here_(Hot_2002_Remix)
# Cache hit: http://tmbw.net/wiki/Lyrics:Doctor_Worm
# Cache hit: http://tmbw.net/wiki/Lyrics:Snail_Shell
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Guitar
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Statue_Got_Me_High
# Cache hit: http://tmbw.net/wiki/Lyrics:Istanbul_(Not_Constantinople)
# Cache hit: http://tmbw.net/wiki/Lyrics:Birdhouse_In_Your_Soul
# Cache hit: http://tmbw.net/wiki/Lyrics:They%27ll_Need_A_Crane
# Cache hit: http://tmbw.net/wiki/Lyrics:Purple_Toupee
# Cache hit: http://tmbw.net/wiki/Lyrics:Ana_Ng
# Cache hit: http://tmbw.net/wiki/Lyrics:(She_Was_A)_Hotel_Detective
# Cache hit: http://tmbw.net/wiki/Lyrics:Don%27t_Let%27s_Start
# Cache hit: http://tmbw.net/wiki/Lyrics:Put_Your_Hand_Inside_The_Puppet_Head
# Cache hit: http://tmbw.net/wiki/Lyrics:Particle_Man
# Cache hit: http://tmbw.net/wiki/Lyrics:Istanbul_(Not_Constantinople)
# Cache miss: http://tmbw.net/wiki/Giants_Jubilee
# Cache hit: http://tmbw.net/wiki/Lyrics:We%27re_The_Replacements
# Cache hit: http://tmbw.net/wiki/Lyrics:When_It_Rains_It_Snows
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Famous_Polka
# Cache hit: http://tmbw.net/wiki/Lyrics:Untitled
# Cache hit: http://tmbw.net/wiki/Lyrics:For_Science
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Biggest_One
# Cache hit: http://tmbw.net/wiki/Lyrics:Kiss_Me,_Son_Of_God_(Alternate_Version)
# Cache hit: http://tmbw.net/wiki/Lyrics:Mr._Klaw
# Cache hit: http://tmbw.net/wiki/Lyrics:Critic_Intro
# Cache hit: http://tmbw.net/wiki/Lyrics:Now_That_I_Have_Everything
# Cache hit: http://tmbw.net/wiki/Lyrics:Mainstream_U.S.A.
# Cache hit: http://tmbw.net/wiki/Lyrics:Fake_Out_In_Buenos_Aires
# Cache hit: http://tmbw.net/wiki/Lyrics:Greek_Number_Three
# Ran into an error on http://tmbw.net/wiki/Lyrics:Greek_Number_Three ('NoneType' object has no attribute 'text')
# Cache hit: http://tmbw.net/wiki/Lyrics:I_Hope_That_I_Get_Old_Before_I_Die_(Demo)
# Cache hit: http://tmbw.net/wiki/Lyrics:I%27m_Def_(Edit)
# Cache hit: http://tmbw.net/wiki/Lyrics:Don%27t_Let%27s_Start_(1985_Demo)
# Cache hit: http://tmbw.net/wiki/Lyrics:%2785_Radio_Special_Thank_You
# Cache miss: http://tmbw.net/wiki/Mightathon
# Cache hit: http://tmbw.net/wiki/Lyrics:Hello_Radio
# Cache hit: http://tmbw.net/wiki/Lyrics:It%27s_Not_My_Birthday
# Cache hit: http://tmbw.net/wiki/Lyrics:I%27ll_Sink_Manhattan
# Cache hit: http://tmbw.net/wiki/Lyrics:Nightgown_Of_The_Sullen_Moon
# Cache hit: http://tmbw.net/wiki/Lyrics:The_World%27s_Address_(Joshua_Fried_Remix)
# Cache hit: http://tmbw.net/wiki/Lyrics:Hey,_Mr._DJ,_I_Thought_You_Said_We_Had_A_Deal
# Cache hit: http://tmbw.net/wiki/Lyrics:Lady_Is_A_Tramp
# Cache hit: http://tmbw.net/wiki/Lyrics:Birds_Fly
# Cache hit: http://tmbw.net/wiki/Lyrics:Kitten_Intro
# Cache hit: http://tmbw.net/wiki/Lyrics:Weep_Day
# Cache hit: http://tmbw.net/wiki/Lyrics:The_Big_Big_Whoredom
# Cache hit: http://tmbw.net/wiki/Lyrics:I%27m_Gettin%27_Sentimental_Over_You
# Cache hit: http://tmbw.net/wiki/Lyrics:Become_A_Robot
# Cache hit: http://tmbw.net/wiki/Lyrics:Which_Describes_How_You%27re_Feeling_(Demo)
# Cache hit: http://tmbw.net/wiki/Lyrics:Swing_Is_A_Word
# Cache hit: http://tmbw.net/wiki/Lyrics:Doris_Cunningham
# Cache hit: http://tmbw.net/wiki/Lyrics:Counterfeit_Fake
# Cache hit: http://tmbw.net/wiki/Lyrics:Schoolchildren_Singing_Particle_Man
# Cache miss: http://tmbw.net/wiki/Long_Tall_Weekend
# Cache miss: http://tmbw.net/wiki/Lyrics:Drinkin%27
# Cache miss: http://tmbw.net/wiki/Lyrics:(She_Thinks_She%27s)_Edith_Head
# Cache miss: http://tmbw.net/wiki/Lyrics:Maybe_I_Know
# Cache miss: http://tmbw.net/wiki/Lyrics:Rat_Patrol
# Cache hit: http://tmbw.net/wiki/Lyrics:Token_Back_To_Brooklyn
# Cache miss: http://tmbw.net/wiki/Lyrics:Older
# Cache miss: http://tmbw.net/wiki/Lyrics:Operators_Are_Standing_By
# Cache miss: http://tmbw.net/wiki/Lyrics:Dark_And_Metric
# Cache miss: http://tmbw.net/wiki/Lyrics:Reprehensible
# Cache miss: http://tmbw.net/wiki/Lyrics:Certain_People_I_Could_Name
# Cache miss: http://tmbw.net/wiki/Lyrics:Counterfeit_Faker
# Cache miss: http://tmbw.net/wiki/Lyrics:They_Got_Lost_(Song)
# Cache miss: http://tmbw.net/wiki/Lyrics:Lullabye_To_Nightmares
# Cache miss: http://tmbw.net/wiki/Lyrics:On_Earth_My_Nina
# Cache miss: http://tmbw.net/wiki/Lyrics:The_Edison_Museum
# Cache miss: http://tmbw.net/wiki/Best_Of_The_Early_Years
# Cache hit: http://tmbw.net/wiki/Lyrics:Ana_Ng
# Cache hit: http://tmbw.net/wiki/Lyrics:Purple_Toupee
# Cache hit: http://tmbw.net/wiki/Lyrics:Youth_Culture_Killed_My_Dog
# Cache hit: http://tmbw.net/wiki/Lyrics:Don%27t_Let%27s_Start_(Single_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:Put_Your_Hand_Inside_The_Puppet_Head
# Cache hit: http://tmbw.net/wiki/Lyrics:(She_Was_A)_Hotel_Detective
# Cache hit: http://tmbw.net/wiki/Lyrics:Everything_Right_Is_Wrong_Again
# Cache hit: http://tmbw.net/wiki/Lyrics:Cowtown
# Cache hit: http://tmbw.net/wiki/Lyrics:We%27re_The_Replacements
# Cache hit: http://tmbw.net/wiki/Lyrics:Hide_Away_Folk_Family
# Cache hit: http://tmbw.net/wiki/Lyrics:Don%27t_Let%27s_Start_(Single_Mix)
# Cache hit: http://tmbw.net/wiki/Lyrics:Ana_Ng
# Cache hit: http://tmbw.net/wiki/Lyrics:Youth_Culture_Killed_My_Dog
# Cache hit: http://tmbw.net/wiki/Lyrics:We%27re_The_Replacements
# Cache hit: http://tmbw.net/wiki/Lyrics:Put_Your_Hand_Inside_The_Puppet_Head
# Cache hit: http://tmbw.net/wiki/Lyrics:Purple_Toupee
# Cache hit: http://tmbw.net/wiki/Lyrics:(She_Was_A)_Hotel_Detective
# Cache hit: http://tmbw.net/wiki/Lyrics:Everything_Right_Is_Wrong_Again
# Cache hit: http://tmbw.net/wiki/Lyrics:Cowtown
# Cache hit: http://tmbw.net/wiki/Lyrics:Hide_Away_Folk_Family
# Cache miss: http://tmbw.net/wiki/Live
# Cache hit: http://tmbw.net/wiki/Lyrics:Birdhouse_In_Your_Soul_(Live_STD)
# Cache hit: http://tmbw.net/wiki/Lyrics:Istanbul_(Not_Constantinople)_(Live_STD)
# Cache hit: http://tmbw.net/wiki/Lyrics:Particle_Man_(Live_STD)
# Cache hit: http://tmbw.net/wiki/Lyrics:She%27s_Actual_Size_(Live_STD)
# Cache hit: http://tmbw.net/wiki/Lyrics:XTC_Vs._Adam_Ant_(Live_STD)
# Cache hit: http://tmbw.net/wiki/Lyrics:Till_My_Head_Falls_Off_(Live_STD)
# Cache hit: http://tmbw.net/wiki/Lyrics:S-E-X-X-Y_(Live_STD)
# Cache hit: http://tmbw.net/wiki/Lyrics:They_Got_Lost_(Live_STD)
# Cache hit: http://tmbw.net/wiki/Lyrics:Ana_Ng_(Live_STD)
# Cache hit: http://tmbw.net/wiki/Lyrics:Doctor_Worm
# Cache miss: http://tmbw.net/wiki/Working_Undercover_For_The_Man_(EP)
# Cache miss: http://tmbw.net/wiki/Lyrics:Rest_Awhile
# Cache miss: http://tmbw.net/wiki/Lyrics:Working_Undercover_For_The_Man
# Cache miss: http://tmbw.net/wiki/Lyrics:I_Am_A_Human_Head
# Cache miss: http://tmbw.net/wiki/Lyrics:Empty_Bottle_Collector
# Cache miss: http://tmbw.net/wiki/Lyrics:On_The_Drag
# Cache miss: http://tmbw.net/wiki/Lyrics:Radio_They_Might_Be_Giants_1
# Cache miss: http://tmbw.net/wiki/Lyrics:Radio_They_Might_Be_Giants_2
# Cache miss: http://tmbw.net/wiki/Lyrics:Radio_They_Might_Be_Giants_3
# Cache miss: http://tmbw.net/wiki/Lyrics:Robot_Parade_(Adult_Version)
# Cache miss: http://tmbw.net/wiki/Boss_Of_Me_(Single)
# Cache miss: http://tmbw.net/wiki/Lyrics:Boss_Of_Me
# Cache miss: http://tmbw.net/wiki/Lyrics:Boss_Of_Me_(Original_Edit)
# Cache miss: http://tmbw.net/wiki/Lyrics:Boss_Of_Me_(Instrumental)
# Cache hit: http://tmbw.net/wiki/Lyrics:Boss_Of_Me
# Cache hit: http://tmbw.net/wiki/Lyrics:Reprehensible
# Cache miss: http://tmbw.net/wiki/Lyrics:Mr._Xcitement_(Early_Version)
# Cache hit: http://tmbw.net/wiki/Lyrics:Boss_Of_Me
# Cache hit: http://tmbw.net/wiki/Lyrics:Boss_Of_Me
# Cache hit: http://tmbw.net/wiki/Lyrics:Boss_Of_Me
# Cache hit: http://tmbw.net/wiki/Lyrics:Reprehensible
# Cache hit: http://tmbw.net/wiki/Lyrics:Boss_Of_Me
# Cache miss: http://tmbw.net/wiki/Lyrics:Mr._Xcitement
# Cache hit: http://tmbw.net/wiki/Lyrics:Birdhouse_In_Your_Soul_(Live_STD)
# Cache hit: http://tmbw.net/wiki/Lyrics:Boss_Of_Me
# Cache hit: http://tmbw.net/wiki/Lyrics:Boss_Of_Me
# Cache hit: http://tmbw.net/wiki/Lyrics:Boss_Of_Me
# Cache miss: http://tmbw.net/wiki/TMBG_Unlimited
# Cache miss: http://tmbw.net/wiki/They_Might_Be_Giants_Vs._McSweeney%27s
# Cache miss: http://tmbw.net/wiki/Mink_Car
# Cache miss: http://tmbw.net/wiki/Lyrics:Bangs
# Cache miss: http://tmbw.net/wiki/Lyrics:Cyclops_Rock
# Cache miss: http://tmbw.net/wiki/Lyrics:Man,_It%27s_So_Loud_In_Here
# Cache hit: http://tmbw.net/wiki/Lyrics:Mr._Xcitement
# Cache miss: http://tmbw.net/wiki/Lyrics:Another_First_Kiss
# Cache miss: http://tmbw.net/wiki/Lyrics:I%27ve_Got_A_Fang
# Cache miss: http://tmbw.net/wiki/Lyrics:Hovering_Sombrero
# Cache miss: http://tmbw.net/wiki/Lyrics:Yeh_Yeh
# Cache miss: http://tmbw.net/wiki/Lyrics:Hopeless_Bleak_Despair
# Cache miss: http://tmbw.net/wiki/Lyrics:Drink!
# Cache miss: http://tmbw.net/wiki/Lyrics:My_Man
# Cache miss: http://tmbw.net/wiki/Lyrics:Older_(Mink_Car_Version)
# Cache miss: http://tmbw.net/wiki/Lyrics:Mink_Car_(Song)
# Cache miss: http://tmbw.net/wiki/Lyrics:Wicked_Little_Critta
# Cache miss: http://tmbw.net/wiki/Lyrics:Finished_With_Lies
# Cache miss: http://tmbw.net/wiki/Lyrics:She_Thinks_She%27s_Edith_Head
# Cache hit: http://tmbw.net/wiki/Lyrics:Working_Undercover_For_The_Man
# Cache hit: http://tmbw.net/wiki/Lyrics:Boss_Of_Me
# Cache hit: http://tmbw.net/wiki/Lyrics:Boss_Of_Me
# Cache hit: http://tmbw.net/wiki/Lyrics:Your_Mom%27s_Alright
# Cache hit: http://tmbw.net/wiki/Lyrics:All_MacGyver_On_It
# Cache hit: http://tmbw.net/wiki/Lyrics:Robot_Parade_(Adult_Version)
# Cache hit: http://tmbw.net/wiki/Lyrics:Man,_It%27s_So_Loud_In_Here
# Cache hit: http://tmbw.net/wiki/Lyrics:Boss_Of_Me
# Cache hit: http://tmbw.net/wiki/Lyrics:Cyclops_Rock
# Cache hit: http://tmbw.net/wiki/Lyrics:Another_First_Kiss
# Cache hit: http://tmbw.net/wiki/Lyrics:Bangs
# Cache hit: http://tmbw.net/wiki/Lyrics:My_Man
# Cache hit: http://tmbw.net/wiki/Lyrics:Drink!
# Cache hit: http://tmbw.net/wiki/Lyrics:Your_Mom%27s_Alright
# Cache hit: http://tmbw.net/wiki/Lyrics:Hovering_Sombrero
# Cache hit: http://tmbw.net/wiki/Lyrics:Yeh_Yeh
# Cache hit: http://tmbw.net/wiki/Lyrics:I%27ve_Got_A_Fang
# Cache hit: http://tmbw.net/wiki/Lyrics:Mink_Car_(Song)
# Cache hit: http://tmbw.net/wiki/Lyrics:Hopeless_Bleak_Despair
# Cache hit: http://tmbw.net/wiki/Lyrics:Older_(Mink_Car_Version)
# Cache miss: http://tmbw.net/wiki/Man,_It%27s_So_Loud_In_Here_(EP)
# Cache miss: http://tmbw.net/wiki/Lyrics:Man,_It%27s_So_Loud_In_Here_(Radio_Edit)
# Cache hit: http://tmbw.net/wiki/Lyrics:Man,_It%27s_So_Loud_In_Here
# Cache hit: http://tmbw.net/wiki/Lyrics:Man,_It%27s_So_Loud_In_Here_(Hot_2002_Remix)
# Cache hit: http://tmbw.net/wiki/Lyrics:Man,_It%27s_So_Loud_In_Here_(Radio_Edit)
# ...
# Cache hit: http://tmbw.net/wiki/Lyrics:Ana_Ng
# Cache hit: http://tmbw.net/wiki/Lyrics:Mink_Car_(Song)
# Cache hit: http://tmbw.net/wiki/Lyrics:Electronic_Istanbul_(Not_Constantinople)
# Cache hit: http://tmbw.net/wiki/Lyrics:Words_Are_Like
# Cache hit: http://tmbw.net/wiki/Lyrics:Unctuous_Robot
# Cache miss: http://tmbw.net/wiki/Who_Are_The_Electors%3F_(Single)
# Cache miss: http://tmbw.net/wiki/Lyrics:Who_Are_The_Electors%3F
# Cache miss: http://tmbw.net/wiki/Roman_Songs
# Cache miss: http://tmbw.net/wiki/Lyrics:TECVM_CIRCVMAMBVLARE_NOLO
# Ran into an error on http://tmbw.net/wiki/Lyrics:TECVM_CIRCVMAMBVLARE_NOLO ('NoneType' object has no attribute 'text')
# Cache miss: http://tmbw.net/wiki/Lyrics:NVNC_AVT_NVMQVAM
# Ran into an error on http://tmbw.net/wiki/Lyrics:NVNC_AVT_NVMQVAM ('NoneType' object has no attribute 'text')
# Cache miss: http://tmbw.net/wiki/Lyrics:HAEC_QVOQVE_EST_RES
# Ran into an error on http://tmbw.net/wiki/Lyrics:HAEC_QVOQVE_EST_RES ('NoneType' object has no attribute 'text')
# Cache miss: http://tmbw.net/wiki/Lyrics:CATENAS_MEAS_AMISI
# Ran into an error on http://tmbw.net/wiki/Lyrics:CATENAS_MEAS_AMISI ('NoneType' object has no attribute 'text')
# Cache miss: http://tmbw.net/wiki/Part_Of_You_Wants_To_Believe_Me_(Single)
# Cache miss: http://tmbw.net/wiki/Lyrics:Part_Of_You_Wants_To_Believe_Me
# Cache miss: http://tmbw.net/wiki/Lyrics:Super_Cool
# Cache miss: http://tmbw.net/wiki/Lyrics:I_Can%27t_Remember_The_Dream
# Cache miss: http://tmbw.net/wiki/Lyrics:I_Broke_My_Own_Rule
# Cache miss: http://tmbw.net/wiki/Lyrics:I_Lost_Thursday
# Cache hit: http://tmbw.net/wiki/The_Pamphlet_EP
# Cache miss: http://tmbw.net/wiki/Lyrics:Helicopters_Of_Elves
# Cache miss: http://tmbw.net/wiki/Lyrics:Buckle_Down,_Winsocki
# Cache miss: http://tmbw.net/wiki/Lyrics:There_Will_Be_Sad
# Cache miss: http://tmbw.net/wiki/Lyrics:Fortnight
# Cache hit: http://tmbw.net/wiki/BOOK
# Cache miss: http://tmbw.net/wiki/Lyrics:Synopsis_For_Latecomers
# Cache miss: http://tmbw.net/wiki/Lyrics:Moonbeam_Rays
# Cache hit: http://tmbw.net/wiki/Lyrics:I_Broke_My_Own_Rule
# Cache miss: http://tmbw.net/wiki/Lyrics:Brontosaurus
# Cache miss: http://tmbw.net/wiki/Lyrics:Lord_Snowdon
# Cache miss: http://tmbw.net/wiki/Lyrics:If_Day_For_Winnipeg
# Cache hit: http://tmbw.net/wiki/Lyrics:I_Can%27t_Remember_The_Dream
# Cache miss: http://tmbw.net/wiki/Lyrics:Drown_The_Clown
# Cache miss: http://tmbw.net/wiki/Lyrics:Darling,_The_Dose
# Cache hit: http://tmbw.net/wiki/Lyrics:I_Lost_Thursday
# Cache hit: http://tmbw.net/wiki/Lyrics:Part_Of_You_Wants_To_Believe_Me
# Cache hit: http://tmbw.net/wiki/Lyrics:Super_Cool
# Cache miss: http://tmbw.net/wiki/Lyrics:Wait_Actually_Yeah_No
# Cache miss: http://tmbw.net/wiki/Lyrics:Quit_The_Circus
# Cache miss: http://tmbw.net/wiki/Lyrics:Less_Than_One
# [{'title': 'Everything Right Is Wrong',
#   'by': ' They Might Be Giants',
#   'year': ' 1985',
#   'lyrics': ['Everything right is wrong again',
#    'Just like in The Long, Long Trailer',
#    'All the dishes got broken and the car kept driving',
#    'And nobody would stop to save her',
#    "Wake me when it's over, touch my face",
#    'Tell me every word has been erased',
#    "Don't you want to know the reason",
#    "Why the cupboard's not appealing",
#    "Don't you get the feeling that",
#    "Everything that's right is wrong again",
#    "You're a weasel overcome with dinge",
#    'Weasel overcome but not before the damage done',
#    "The healing doesn't stop the feeling",
#    'Everything right is wrong again',
#    'Just like in the long long trailer',
#    'All the dishes got broken and the car kept driving',
#    'And nobody would stop to save her',
#    'And now the song is over now',
#    'And now the song is over now',
#    'And now the song is over now',
#    'The song is over now',
#    'Everything right is wrong again',
#    'Every movement false, every four is waltz again',
#    "Every five and dime's been gained and spent",
#    'Tell me that you like my float upstream',
#    'Draw the line dividing laugh and scream',
#    'You know everything that I know so I know',
#    "You've heard the voice that makes the silent noise",
#    'That says that',
#    "Everything that's right is wrong again",
#    "You're a weasel overcome with dinge",
#    'Weasel overcome but not before the damage done',
#    "The healing doesn't stop the feeling",
#    'Everything right is wrong again',
#    'Just like in the long long trailer',
#    'All the dishes got broken and the car kept driving',
#    'And nobody would stop to save her'],
#   'album': 'Wiggle Diskette'},
#  {'title': "You'll Miss Me (Demo 1)",
#   'by': ' They Might Be Giants',
#   'year': ' 1985',
#   'lyrics': ["You'll always miss my big ol' body",
#    'In its prime and never shoddy',
#    'As bloodhounds wait down in the lobby',
#    "You'll eulogize my big ol' body",
#    "You'll miss me with effigies",
#    'Lighting up your house like X-mas trees',
#    'As tears roll down, below your knees',
#    "You'll miss me with effigies",
#    'Go find a man to fit my shoes',
#    "Left one's old and the right one's new",
#    'And I bought the right one, just for you',
#    'Go find a man to fit my shoes',
#    'You kill me with the way you talk',
#    'Morticians wait with a shovel and a fork',
#    "But I'll remain sitting on this fence",
#    'My mind a blur of common sense',
#    "You'll see my teeth in the stars above",
#    'Every tree a finger of my glove',
#    'And every time push comes to shove',
#    "You'll see my teeth in the stars above",
#    'Your money talks but my genius walks',
#    "No one to blame, it's not my fault",
#    'As detectives trace my hands with chalk',
#    'Your money talks, my genius walks',
#    "You'll miss me so",
#    'You will miss me so',
#    "You'll miss me so",
#    "You'll miss me",
#    "It must be raining 'cause a man ain't supposed to cry",
#    "I look up and I don't see a cloud",
#    "It must be raining 'cause a man ain't supposed to cry",
#    "But I look up and I don't see a cloud"],
#   'album': 'Wiggle Diskette'},
#  {'title': 'Put Your Hand Inside The Puppet Head (Demo 3)',
#   'by': ' They Might Be Giants',
#   'year': ' 1985',
#   'lyrics': ['As your body floats down third street',
#    'With the burn-smell factory closing up',
#    'Is it sad to say you will romanticize',
#    "All the things you've know before?",
#    'It was not not not so great',
#    'It was not not not so great',
#    'And as you take a bath in that beaten path',
#    "There's a pounding at the door",
#    "Well it's a mighty zombie ",
#    'Talking of some love of posterity',
#    "That said the good ol' days never say goodbye",
#    'If you keep this in your mind',
#    "You need some lo-lo-lovin' arms",
#    "You need some lo-lo-lovin' arms",
#    'And as you fall from grace the only words you say are',
#    'Put your hand inside the puppet head',
#    'Put your hand inside the puppet head',
#    'Put your hand inside, put your hand inside',
#    'Put your hand inside the puppet head',
#    'Ads up in the subway are the work of',
#    'Someone trying to please their boss',
#    "You know the guy's a pig",
#    'We all know what he wants ',
#    'Is just to please somebody else',
#    'If the pu-pu-puppet head',
#    'Was only bu-bu-busted in',
#    "It'd be a better thing",
#    'For everyone involved',
#    "And we wouldn't have to cry",
#    'Put your hand inside the puppet head',
#    'Put your hand inside the puppet head',
#    'Put your hand inside, put your hand inside',
#    'Put your hand inside the puppet head',
#    'Things!',
#    'Gotta do!',
#    'Head!',
#    'Puppet head!',
#    '(No! Gotta do!) Memo to myself',
#    '(Head! Puppet head!) Do the dumb things I gotta do',
#    '(Things! Gotta do! Hey! Puppet head!) Touch the puppet head',
#    'Quit my job down at the subway',
#    "Didn't have to write no one a goodbye note",
#    "That said the check's in the mail",
#    "And I'll see you at church",
#    "And don't you ever change",
#    'If the pu-pu-puppet head',
#    'Was only bu-bu-busted in',
#    "I'll see you after school",
#    'Put your hand inside the puppet head',
#    'Put your hand inside the puppet head',
#    'Put your hand inside, put your hand inside',
#    'Put your hand inside the puppet head',
#    'Put your hand inside the puppet head',
#    'Put your hand inside the puppet head',
#    'Put your hand inside, put your hand inside',
#    'Put your hand inside the puppet head'],
#   'album': '1985 Demo Tape'},
#  {'title': 'When It Rains It Snows (Demo)',
#   'by': ' They Might Be Giants',
#   'year': ' 1985',
#   'lyrics': ['Shh',
#    "There's a knock on the door that I adore",
#    "There's a face at the window, a smiling yellow face",
#    "There's a knock on the door",
#    "And if I were at home, they'd find me there",
#    "There's a note on the door that I would see",
#    "And the furniture's barely been moved from where it was",
#    "There's a note on the door",
#    'And the note will say when it rains, it snows',
#    'When it rains, it snows',
#    'I wonder why',
#    'And now I know',
#    'That when it rains, it snows',
#    "There's a nut with a shotgun, bang bang bang",
#    "There's a waitress, a doctor, a fireman with a hat",
#    "There's a nut with a gun",
#    "There's enough that they'll never know which one",
#    'When it rains, it snows',
#    'I wonder why',
#    'And now I know',
#    'That when it rains, it snows'],
#   'album': '1985 Demo Tape'},
#  {'title': 'Number Three (1985 Demo)',
#   'by': ' They Might Be Giants',
#   'year': ' 1985',
#   'lyrics': ["There's only two songs in me and I just wrote the third",
#    "Don't know where I got the inspiration or how I wrote the words",
#    "Spent my whole life just digging up my music's shallow grave",
#    'For the two songs in me and the third one I just made',
#    'A rich man once told me',
#    '"Hey, life\'s a funny thing"',
#    'A poor man once told me',
#    "That he can't afford to speak",
#    "Now I'm in the middle like a bird without a beak 'cause",
#    "There's just two songs in me and I just wrote the third",
#    "Don't know where I got the inspiration or how I wrote the words",
#    "Spent my whole life just digging up my music's shallow grave",
#    'For the two songs in me and the third one I just made',
#    'So I went to the President',
#    "And I asked old what's-his-name",
#    "Has he ever gotten writer's block",
#    'Or something like the same',
#    'He just started talking',
#    'Like he was on TV',
#    '"If there\'s just two songs in ya, boy',
#    'Whaddaya want from me?"',
#    'So I bought myself some denim pants',
#    'And a silver guitar',
#    'But I politely told the ladies',
#    '"You\'ll still have to call me Sir',
#    'Because I have to keep my self-respect',
#    "I'll never be a star",
#    "Since there's just two songs in me",
#    'And this is Number Three"'],
#   'album': '1985 Demo Tape'},
#  {'title': "Don't Let's Start (1985 Demo)",
#   'by': ' They Might Be Giants',
#   'year': ' 1985',
#   'lyrics': ["Don't, don't, don't let's start",
#    'This is the worst part',
#    'I could believe for all the world',
#    'That you were my precious little girl',
#    "But don't, don't, don't let's start",
#    "I've got a weak heart",
#    "And I don't get around how you get around",
#    "Don't, Don't!",
#    "I don't want to live in this world anymore",
#    "I don't want to live in this world anymore",
#    "Don't, don't, don't let's start",
#    'This is the worst part',
#    'I could believe for all the world',
#    'That you were my precious little girl',
#    "But don't, don't, don't let's start",
#    "I've got a weak heart",
#    "And I don't get around how you get around"],
#   'album': '1985 Demo Tape'},
#  {'title': "You'll Miss Me (Demo 2)",
#   'by': ' They Might Be Giants',
#   'year': ' 1985',
#   'lyrics': ["You'll always miss",
#    "My big ol' body",
#    'In its prime and never shoddy',
#    'While bloodhounds wait',
#    'Down in the lobby',
#    "You'll eulogize my big ol' body",
#    "You'll miss me",
#    'With effigies',
#    'Lighting up your house like X-mas trees',
#    'As tears roll down, below your knees',
#    "You'll miss me",
#    'With effigies',
#    'Go find a man to fit my shoes',
#    "Left one's old and the right one's new",
#    'And I bought the right one, just for you',
#    'Go find a man to fit my shoes',
#    'You kill me with the way you talk',
#    'Morticians wait with a shovel and a fork',
#    "But I'll remain sittin' on this fence",
#    'My mind a blur of common sense',
#    "You'll see my teeth in the stars above",
#    'Every tree a finger of my glove',
#    'And every time push comes to shove',
#    "You'll see my teeth in the stars above",
#    'Your money talks but my genius walks',
#    "No one to blame, it's not my fault",
#    'As detectives trace my hands with chalk',
#    'Your money talks but my genius walks',
#    "You'll miss me so",
#    "You'll miss me",
#    "You'll miss me but I'm already dead",
#    "It must be raining 'cause a man ain't supposed to cry",
#    "But I look up and I don't see a cloud",
#    "It must be raining 'cause a man ain't supposed to cry",
#    "But I look up and I don't see a cloud",
#    'Anywhere'],
#   'album': '1985 Demo Tape'},
#  {'title': 'I Hope That I Get Old Before I Die (Demo)',
#   'by': ' They Might Be Giants',
#   'year': ' 1985',
#   'lyrics': ['Sometimes I feel like being wispy',
#    'And once in a while I feel like being dry',
#    "But we're doomed and we're drowned",
#    'By this feeling we surround',
#    'So I hope that I get old before I die',
#    'Ohhhhh',
#    "It's a long, long rope they use to hang you soon I hope",
#    "And I wonder why this hasn't happened",
#    'Why, why, why',
#    "And I think about the dirt that I'll be wearing for a shirt",
#    'And I hope that I get old before I die',
#    'Clear off the kitchen table darling',
#    'For on the kitchen table I must lie',
#    "I'm just tired for my wife",
#    'Served the banquet of my life',
#    'And I hope that I get old before I die',
#    'Ohhhhh',
#    "It's a long, long rope they use to hang you soon I hope",
#    "And I wonder why this hasn't happened",
#    'Why, why, why',
#    "And I think about the dirt that I'll be wearing for a shirt"],
#   'album': '1985 Demo Tape'},
#  {'title': 'The Biggest One (1985 Demo)',
#   'by': ' They Might Be Giants',
#   'year': ' 1985',
#   'lyrics': ['The water running down that pipe',
#    'Looks like a snake to me',
#    'By "Doc\'s Sugar Bowl" my coffee gets cold',
#    "'Cause I don't want to see",
#    'That I got no one to blame but my fat self',
#    'I got no one to blame but my fat self',
#    "I'm the biggest one",
#    "I'm the biggest one",
#    'I got no one to blame but my fat self',
#    'Should have changed that stupid lock',
#    'Should have thrown away the key',
#    'No, no, not I, I will survive',
#    'Right down here on my knees',
#    "'Cause I got no one to blame but my fat self",
#    'I got no one to blame but my fat self',
#    "I'm the biggest one",
#    "I'm the biggest one",
#    'I got no one to blame but my fat self'],
#   'album': '1985 Demo Tape'},
#  {'title': '32 Footsteps',
#   'by': ' They Might Be Giants',
#   'year': ' 1985',
#   'lyrics': ["32 footsteps leading to the room where the paint doesn't want to dry",
#    '32 footsteps running down the road where the dirt reaches the sky',
#    '32 feathers in my brand new Indian headdress',
#    '32 new moons shining in 32 skies',
#    "What's the reason? Why'd she go?",
#    "Where's my baby? I don't know",
#    '32 footsteps, counted them myself, 32 footsteps',
#    'Bing bang bingalong cing cang cingalong',
#    'Ding dang dingalong day',
#    'Fing fang fingalong ging gang gingalong',
#    'Hing hang hingalong hay',
#    'Jing jang jingalong king kang kingalong',
#    'Ling lang lingalong lay',
#    'Ming mang mingalong ning nang ningalong',
#    'Ping pang pingalong pay',
#    "What's the reason? Why'd she go?",
#    "Where's my baby? I don't know",
#    '32 footsteps, counted them myself, 32 footsteps',
#    '32 lies my ears never saw when the floorboards gave way',
#    '32 walls come tumbling down and the night turns to day',
#    '32 infantrymen running in place',
#    '32 boxcars, all of them have your face',
#    "What's the reason? Why'd she leave?",
#    "Don't you know we're on the eve of",
#    '32 footsteps? Counted them myself, 32 footsteps',
#    '(no) 28',
#    '(no) 29',
#    '30 (no)',
#    '31'],
#   'album': '1985 Demo Tape'}]

# %% [markdown]
# Using Make to Make
# ==================
#
# Its a useful exercise to convert this to a build-system orchestrated set of tasks. What we want to do is isolate each step. These are:
#
# 1. grab the album list
# 2. grab the song list (from the album list)
# 3. grab the song data (from the song list)
#
# See the makefiles.
#
# Scraping Async Data
# ===================
#
# Lots of web pages load their data _after_ the page loads. Consider almost any of the pages on this great website:
#
# https://bl.ocks.org/armollica/3b5f83836c1de5cca7b1d35409a013e3
#
# If we load this into our Python session:

# %%
page = get("https://bl.ocks.org/armollica/3b5f83836c1de5cca7b1d35409a013e3")
page
# Out:
# Cache miss: https://bl.ocks.org/armollica/3b5f83836c1de5cca7b1d35409a013e3
# '<!DOCTYPE html>\n<meta charset="utf-8">\n<meta name="viewport" content="width=1000">\n<meta name="twitter:card" content="summary">\n<meta name="twitter:site" content="@mbostock">\n<meta property="og:url" content="https://bl.ocks.org/armollica/3b5f83836c1de5cca7b1d35409a013e3">\n<meta property="og:title" content="Joyplot">\n<meta property="og:description" content="Andrew Mollica’s Block 3b5f83836c1de5cca7b1d35409a013e3">\n<meta property="og:image" content="https://bl.ocks.org/armollica/raw/3b5f83836c1de5cca7b1d35409a013e3/783d1bbc2dd3aabbfcba83ece4a670de6f1ec371/thumbnail.png">\n<title>Joyplot - bl.ocks.org</title>\n<link rel="icon" href="/favicon.png">\n<link rel="canonical" href="https://bl.ocks.org/armollica/3b5f83836c1de5cca7b1d35409a013e3">\n<style>\n\n@import url("/style.css");\n\n</style>\n\n  <a class="announce" href="https://observablehq.com/?utm_source=blocks">\n    <div class="column">\n      Join <b>Observable</b> to explore and create live, interactive data visualizations.\n    </div>\n  </a>\n\n<header>\n  <div class="column">\n    <div class="navigation">\n      <a href="/">Popular</a>\n      / <a href="/-/about">About</a>\n    </div>\n    <a class="user" href="/armollica"><img class="avatar" src="https://avatars.githubusercontent.com/u/5270903?v=4&amp;s=60" width="30" height="30">Andrew Mollica</a>’s\n    Block <a class="gist gist-id self" title="View Gist on GitHub." href="https://gist.github.com/armollica/3b5f83836c1de5cca7b1d35409a013e3">3b5f83836c1de5cca7b1d35409a013e3</a>    <div class="date">Updated July 15, 2017</div>\n  </div>\n</header>\n\n<div class="column">\n  <h1>Joyplot</h1>\n  <div class="index">\n    <iframe sandbox="allow-popups allow-scripts allow-forms allow-same-origin" src="/armollica/raw/3b5f83836c1de5cca7b1d35409a013e3/783d1bbc2dd3aabbfcba83ece4a670de6f1ec371/" marginwidth="0" marginheight="0" style="height:600px;" scrolling="no"></iframe>\n  </div>\n  <div class="index-pop">\n    <a target="_blank" title="Open Block 3b5f83836c1de5cca7b1d35409a013e3 a new window." href="/armollica/raw/3b5f83836c1de5cca7b1d35409a013e3?raw=true">Open<svg height="16" width="12"><path d="M11 10h1v3c0 0.55-0.45 1-1 1H1c-0.55 0-1-0.45-1-1V3c0-0.55 0.45-1 1-1h3v1H1v10h10V10zM6 2l2.25 2.25-3.25 3.25 1.5 1.5 3.25-3.25 2.25 2.25V2H6z"></path></svg></a>\n  </div>\n  <div class="gist-readme" data-key="README.md"></div>\n  <div class="gist-sources">\n    <div class="gist-source" data-key="index.html">\n      <h2>index.html<a name="index.html" class="anchor" href="#index.html">#</a></h2>\n      <pre><code>…</code></pre>\n    </div>\n    <div class="gist-source" data-key="Makefile">\n      <h2>Makefile<a name="Makefile" class="anchor" href="#Makefile">#</a></h2>\n      <pre><code>…</code></pre>\n    </div>\n    <div class="gist-source" data-key="process-activity.R">\n      <h2>process-activity.R<a name="process-activity.R" class="anchor" href="#process-activity.R">#</a></h2>\n      <pre><code>…</code></pre>\n    </div>\n  </div>\n  <div class="gist-license">\n    <h2>LICENSE<a name="license" class="anchor" href="#license">#</a></h2>\n    This block appears to have <a target=\'_blank\' href="https://choosealicense.com/no-license/">no license</a>. Please contact <a target=\'_blank\' href=\'https://github.com/armollica\'>the author</a> to request a license.\n  </div>\n</div>\n\n<script src="https://d3js.org/d3.v6.min.js"></script>\n<script src="https://cdnjs.cloudflare.com/ajax/libs/showdown/1.8.1/showdown.min.js" integrity="sha384-Mcx6WhltjdlkIwTWetAJIBNgD0lLtUcl//A7Ksp/vmVZVD2rzQ949wtmoehrDJd/" crossorigin="anonymous"></script>\n<script src="https://cdnjs.cloudflare.com/ajax/libs/highlight.js/9.12.0/highlight.min.js" integrity="sha256-/BfiIkHlHoVihZdc6TFuj7MmJ0TWcWsMXkeDFwhi0zw=" crossorigin="anonymous"></script>\n<script>\n\nhljs.configure({classPrefix: ""});\nshowdown.setFlavor("github");\n\nvar gist = {"public":true,"protocol":"https","sha":"783d1bbc2dd3aabbfcba83ece4a670de6f1ec371","files":{".DS_Store":{"language":nu ...

# %% [markdown]
# Take my word for it: the data which makes these pretty plots isn't here. Thats because some Javascript (d3's "tsv" function) loads the data _after_ the page loads. When we get a page with our `get` function we just get the empty JSON. It doesn't execute any Javascript code or even have a document object. Unfortunately, even if we parse our page with beautifulsoup we just parse the HTML. No Javascript is executed.
#
# Are we out of luck?
#
# Visit the Network Tab
# =====================
#
# Nope! If we open our inspector, we can visit the network tab, click refresh, and see all the data the page loads. Typically we can then find the URL from which the data is loaded.
#
# Sure enough:
#
# https://bl.ocks.org/armollica/raw/3b5f83836c1de5cca7b1d35409a013e3/783d1bbc2dd3aabbfcba83ece4a670de6f1ec371/data.tsv
#
# If we now invoke this:

# %%
content = get("https://bl.ocks.org/armollica/raw/3b5f83836c1de5cca7b1d35409a013e3/783d1bbc2dd3aabbfcba83ece4a670de6f1ec371/data.tsv")
content[0:100]
# Out:
# Cache miss: https://bl.ocks.org/armollica/raw/3b5f83836c1de5cca7b1d35409a013e3/783d1bbc2dd3aabbfcba83ece4a670de6f1ec371/data.tsv
# 'activity\ttime\tp\tp_peak\tp_smooth\nRunning\t1440.0\t6.45223543281662e-5\t0.04402262110550772\t0.04402262110'

# %% [markdown]
# We can now convert this to a data frame, if we want:

# %%
import pandas as pd
import io

pd.read_csv(io.StringIO(content), sep="\t")
# Out:
#                              activity    time         p    p_peak  p_smooth
# 0                             Running  1440.0  0.000065  0.044023  0.044023
# 1              Playing racquet sports  1440.0  0.000000  0.000000  0.000000
# 2     Weightlifting/strength training  1440.0  0.000080  0.050097  0.050097
# 3                              Hiking  1440.0  0.000000  0.000000  0.000000
# 4                              Biking  1440.0  0.000007  0.008702  0.008702
# ...                               ...     ...       ...       ...       ...
# 8087                    Rollerblading  1440.0  0.000026  0.080469  0.080469
# 8088                          Golfing  1440.0  0.000018  0.007607  0.007607
# 8089               Playing volleyball  1440.0  0.000000  0.000000  0.000000
# 8090                          Boating  1440.0  0.000022  0.033145  0.033145
# 8091                 Playing baseball  1440.0  0.000000  0.000000  0.000000
#
# [8092 rows x 5 columns]

# %% [markdown]
# The idea here is: if you can't find the data you want in the HTML, load your browser, look in the Network Tab and and see if you can find things like:
#
# 1. JSON
# 2. CSV/TSV/TXT
# 3. HTML/XML
#
# Copy the url and scrape or load that data directly.
#
# Recap
# =====
#
# Web Scraping is simple and fun. The basic idea is almost always the same:
#
# 1. Find a page that has the data you want.
# 2. If there are many such pages, find a page which lists them all or otherwise find a way to navigate through them by finding "a" tags (links)
# 3. If you can't find the data in the HTML, try looking at the network activity tab to see if its load after the page is loaded
# 4. Make sure to cache your requests so that you don't look like a DOS attack and don't issue a million requests a minute or you might get your IP blocked. Its also just rude.
# 5. If you're pages are behind a login you can usually get around this by copying the header information from a browser after you've logged in, but scraping such pages may be illegal in the US.
# 6. Its very useful to break down complicated scraping tasks into smaller bits and put them together with a makefile.
