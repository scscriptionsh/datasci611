# %% [markdown]
# Pandas
# ======
#
# Back when I was a lad the data frame was an abstraction limited to R and we managed our data using a pile of homogeneos but distinct objects. Unsurprisingly, R still has the best data frame support.
#
# Pandas is what Python has and its very Pythonic (in the sense that its weird, has a confusing API, and an even stranger set of internal representations). But we must accept it as the way of things.
#
# Fun Facts
# ==========
#
# There are a few packages which implement dplyr like programming for DataFrames in Python. You can use these if you just want to get in and get out in Python without the headache of using pandas directly. Unfortunately, if you want to do any serious work in Python, or if it is the main language that a project you are working on uses, then you probably want to just program with pandas.
#
# ```
# RUN pip3 install dplython
# ```
#
# A more friendly alternative to using is to use SQL to manipulate your Python Dataframes. This is a little unusual but your collaborators will almost all certainly have a passing familiarity with SQL.
#
# ```
# RUN pip3 install pandasql
# ```
#
# We'll show some examples of what this looks like later.
#
# Dot Chaining
# ============
#
# Recall that Python is single dispatch object oriented. That means objects carry around their methods and methods are like functions which always receive their object as their first argument.
#
# An interesting thing can happen when you write methods that return themselves (or similar objects): you can chain a bunch of "commands" together into a dot-chain and write a concise little sequence of instructions which apply (conceptually) to a single object in a pipeline:

# %%
class StackProgram:
    stack = None;
    def __init__(self):
        self.stack = [];
    def push(self, v):
        self.stack.append(v)
        return self;
    def add(self):
        a = self.stack.pop();
        b = self.stack.pop();
        self.push(a+b);
        return self;
    def times(self):
        a = self.stack.pop();
        b = self.stack.pop();
        self.push(a*b);
        return self;
    def div(self):
        a = self.stack.pop();
        b = self.stack.pop();
        self.push(a/b);
        return self;
    def sub(self):
        a = self.stack.pop();
        b = self.stack.pop();
        self.push(a-b);
        return self;
    def prnt(self):
        a = self.stack.pop();
        print(a)
        return self;
    def dup(self):
        self.stack.append(self.stack[-1]);
        return self;

# %% [markdown]
# Note that all our methods return `self`. That we we can write a little program like this:

# %%
StackProgram().push(1).push(2).add().prnt()
# Out:
# 3

# %% [markdown]
# Note that if you want to run this over multiple lines without escaping the newlines you need to enclose the whole thing in parentheses.

# %%
(StackProgram()
 .push(123)
 .push(200)
 .times().prnt())
# Out:
# 24600

# %% [markdown]
# If you squint this may resemble the usage of the `pipeline` operator `%>%` from R. The main restriction which applies to these `dot pipes` is that the object itself must implement the method you want to use, whereas any function whatsoever (which makes sense) in a `%>%` pipe may be used. However, this is the closest and most idiomatic way of writing a pipeline in Python. You'll see this many more places than Pandas.
#
# Translating Dplyr to Pandas
# ===========================
#
# Once you get a hang of this, translating Dplyr Code to Pandas is just a matter of digging up the right method or combination of methods to do what you want and chaining them together.

# %%
# !wget http://millionsongdataset.com/sites/default/files/AdditionalFiles/track_metadata.db
# Out:
# --2021-10-27 15:27:58--  http://millionsongdataset.com/sites/default/files/AdditionalFiles/track_metadata.db
# Resolving millionsongdataset.com (millionsongdataset.com)... 172.104.14.177
# Connecting to millionsongdataset.com (millionsongdataset.com)|172.104.14.177|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 746180608 (712M)
# Saving to: ‘track_metadata.db.1’
#
# track_metadata.db.1 100%[===================>] 711.61M  16.1MB/s    in 45s
#
# 2021-10-27 15:28:43 (15.9 MB/s) - ‘track_metadata.db.1’ saved [746180608/746180608]

# %%
import pandas as pd;
songs = pd.read_csv("songs.csv");

# %%
songs.head() # head(songs)
# Out:
#              track_id              title             song_id  \
# 0  TRMMMYQ128F932D901       Silent Night  SOQMMHC12AB0180CB8
# 1  TRMMMKD128F425225D        Tanssi vaan  SOVFVAK12A8C1350D9
# 2  TRMMMRX128F93187D9  No One Could Ever  SOGTUKN12AB017F4F1
# 3  TRMMMCH128F425532C      Si Vos Querés  SOBNYVR12A8C13558C
# 4  TRMMMWA128F426B589   Tangle Of Aspens  SOHSBXH12A8C13B0DF
#
#                                 release           artist_id  \
# 0                 Monster Ballads X-Mas  ARYZTJS1187B98C555
# 1                           Karkuteillä  ARMVN3U1187FB3A1EB
# 2                                Butter  ARGEKB01187FB50750
# 3                               De Culo  ARNWYLR1187B9B2F9C
# 4  Rene Ablaze Presents Winter Sessions  AREQDTE1269FB37231
#
#                             artist_mbid       artist_name   duration  \
# 0  357ff05d-848a-44cf-b608-cb34b5701ae5  Faster Pussy cat  252.05506
# 1  8d7ef530-a6fd-4f8f-b2e2-74aec765e0f9  Karkkiautomaatti  156.55138
# 2  3d403d44-36ce-465c-ad43-ae877e65adc4    Hudson Mohawke  138.97098
# 3  12be7648-7094-495f-90e6-df4189d68615       Yerba Brava  145.05751
# 4                                   NaN        Der Mystic  514.29832
#
#    artist_familiarity  artist_hotttnesss  year  track_7digitalid  shs_perf  \
# 0            0.649822           0.394032  2003           7032331        -1
# 1            0.439604           0.356992  1995           1514808        -1
# 2            0.643681           0.437504  2006           6945353        -1
# 3            0.448501           0.372349  2003           2168257        -1
# 4            0.000000           0.000000     0           2264873        -1
#
#    shs_work
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
songs.query('artist_name == "Guided By Voices"').head() # songs %>% filter(artist_name == "Guided By Voices")
# Out:
#                   track_id                          title             song_id  \
# 145418  TRHVATC128F4249685                    Liar's Tale  SOMPJZX12A8C137161
# 169868  TRCIYDU128F425B61A                Blue Moon Fruit  SOXPAEN12A58A78D36
# 206491  TRRZETT128F42376B3                     Break Even  SOBLFLB12A58A7AB0A
# 223987  TRRDIWV128F424120B  Choking Tara (Creamy Version)  SORYPZZ12A8C133A45
# 231053  TRBMBOA12903CEBA97                   The Tumblers  SOJZBJQ12AC468D820
#
#                                                   release           artist_id  \
# 145418                    Self-Inflicted Aerial Nostalgia  ARI28971187FB57288
# 169868                             Get Out Of My Stations  ARI28971187FB57288
# 206491                                     The Grand Hour  ARI28971187FB57288
# 223987  Everything Is Nice: The Matador Records 10th A...  ARI28971187FB57288
# 231053                              Devil Between My Toes  ARI28971187FB57288
#
#                                  artist_mbid       artist_name   duration  \
# 145418  6c85f4c3-026c-4c16-9a7c-f546f42ed0fb  Guided By Voices  117.02812
# 169868  6c85f4c3-026c-4c16-9a7c-f546f42ed0fb  Guided By Voices   93.20444
# 206491  6c85f4c3-026c-4c16-9a7c-f546f42ed0fb  Guided By Voices  148.81914
# 223987  6c85f4c3-026c-4c16-9a7c-f546f42ed0fb  Guided By Voices  136.30649
# 231053  6c85f4c3-026c-4c16-9a7c-f546f42ed0fb  Guided By Voices  159.71220
#
#         artist_familiarity  artist_hotttnesss  year  track_7digitalid  \
# 145418            0.762434           0.463792  1989           2705734
# 169868            0.762434           0.463792  1994           2783997
# 206491            0.762434           0.463792  1993           2627978
# 223987            0.762434           0.463792  1999           2082231
# 231053            0.762434           0.463792  1987           6649946
#
#         shs_perf  shs_work
# 145418        -1         0
# 169868        -1         0
# 206491        -1         0
# 223987        -1         0
# 231053        -1         0

# %% [markdown]
# Manifestly, the pandas equivalent of 'filter' is 'query' which takes a string rather than an expression. `query` allows you to write expressions which are Python-like without being exactly like Python. There are several differences:
#
# 1. slight differences in operator precedence
# 2. use @variable to reference variables in the enclosing scope
# 3. use `some name` to reference columns which have names which aren't valid Python variable names.
#
# There are other issues which may crop up. At the expense of performance you can tell query that you really want to run real Python code by saying `parser='python'` as a keyword argument. This is slower.
#
# Select :: Filter
# ================
#
# Very confusingly what we called `select` in in SQL and in dplyr Pandas calls `filter,` a truly egregiously bad name.

# %%
songs.query('artist_name == "Guided By Voices"').filter(['title','release','year']).sort_values(['release','year']) # 
# songs %>% filter(artist_name == "Guided By Voices") %>% select(title, release, year) %>% arrange(release, year)
# Out:
#                                                 title  \
# 231053                                   The Tumblers
# 294346                                 3 Year Old Man
# 670994                   A Portrait Destroyed By Fire
# 803774                                    Old Battery
# 914723                                      Dog's Out
# 934808                              Hey Hey_ Spaceman
# 955064                                        Artboat
# 223987                  Choking Tara (Creamy Version)
# 628868                                Dusty Bushworms
# 890680                                     Melted Pat
# 169868                                Blue Moon Fruit
# 662530                       Queen Of Second Guessing
# 712917  Postal Blowfish (Boot & Saddle_ Phila._ 1/93)
# 634022                                Postal Blowfish
# 781846                                      Barricade
# 833549                          The Drinking Jim Crow
# 866819                                  Common Rebels
# 145418                                    Liar's Tale
# 751806                  Radio Show (Trust The Wizard)
# 206491                                     Break Even
# 231910                                         No Sky
# 246671                      To Remake The Young Flyer
# 411171                     Burning Flag Birthday Suit
# 553261                        Man Called Aerodynamics
# 580128                              Lord Of Overstock
# 600315                                 Dont Stop Now
# 632542                               Rhine Jive Click
# 304349                                         Dusted
#
#                                                   release  year
# 231053                              Devil Between My Toes  1987
# 294346                              Devil Between My Toes  1987
# 670994                              Devil Between My Toes  1987
# 803774                              Devil Between My Toes  1987
# 914723                              Devil Between My Toes  1987
# 934808                              Devil Between My Toes  1987
# 955064                              Devil Between My Toes  1987
# 223987  Everything Is Nice: The Matador Records 10th A...  1999
# 628868                             Get Out Of My Stations  1992
# 890680                             Get Out Of My Stations  1992
# 169868                             Get Out Of My Stations  1994
# 662530                             Get Out Of My Stations  1994
# 712917                             Get Out Of My Stations  1994
# 634022                       Kids In The Hall Brain Candy  1994
# 781846                                            Sandbox  1987
# 833549                                            Sandbox  1987
# 866819                                            Sandbox  1987
# 145418                    Self-Inflicted Aerial Nostalgia  1989
# 751806                    Self-Inflicted Aerial Nostalgia  1989
# 206491                                     The Grand Hour  1993
# 231910                   Under The Bushes Under The Stars  1996
# 246671                   Under The Bushes Under The Stars  1996
# 411171                   Under The Bushes Under The Stars  1996
# 553261                   Under The Bushes Under The Stars  1996
# 580128                   Under The Bushes Under The Stars  1996
# 600315                   Under The Bushes Under The Stars  1996
# 632542                   Under The Bushes Under The Stars  1996
# 304349                                   Vampire On Titus  1993

# %% [markdown]
# Note that we also snuck in a `sort_values` (Python) for `arrange` (dplyr) or `order by` (SQL).
#
# Grouping and Summarizing
# ========================
#
# This stuff works a little differently and I don't like it! Looks like we have about

# %%
(songs
 .eval('dummy = 1')
 .groupby('artist_name',as_index=False)
 .agg({'dummy':'sum'})
 .rename(columns={'dummy':'count'})
 .sort_values(['count'], ascending=False)
.head(20))

# songs %>% group_by(artist_name) %>% tally() %>% rename(count=n) %>% arrange(desc(count))
# Out:
#               artist_name  count
# 42535     Michael Jackson    194
# 31923         Johnny Cash    193
# 5890         Beastie Boys    187
# 31187           Joan Baez    181
# 45505        Neil Diamond    176
# 18740         Duran Duran    175
# 1356            Aerosmith    173
# 22917     Franz Ferdinand    173
# 51352           Radiohead    173
# 65179  The Rolling Stones    171
# 62901           The Doors    171
# 30984        Jimi Hendrix    170
# 62707            The Cure    169
# 21583         Faron Young    168
# 19952     Ella Fitzgerald    168
# 20080       Elvis Presley    167
# 34181        Kenny Rogers    167
# 58030       Sonny Rollins    166
# 70846       Willie Nelson    165
# 69361               Venom    164

# %% [markdown]
# One wonders how this material was sampled.
# At this point its probably worth getting into plotting, since we don't always want to go back into R to make a few plots.
#
# As an R partisan, I think the best plotting system in terms of convenience is ggplot, but we may as well review how to do it in Python without using plotnine.

# %%
songs_per_year = (songs
 .query('year >= 1900')
 .eval('dummy = 1')
 .groupby('year', as_index=False)
 .agg({'dummy':'sum'})
 .rename(columns={'dummy':'count'})
 .sort_values(['year'], ascending=False))
songs_per_year
# Out:
#     year  count
# 88  2011      1
# 87  2010   9397
# 86  2009  31051
# 85  2008  34770
# 84  2007  39414
# ..   ...    ...
# 4   1927     43
# 3   1926     19
# 2   1925      7
# 1   1924      5
# 0   1922      6
#
# [89 rows x 2 columns]

# %% [markdown]
# Plotting
# ========
#
# May as well plot some data!
#
# Matplotlib
# ----------

# %%
import matplotlib.pyplot as plt

plt.plot(songs_per_year["year"], songs_per_year["count"])

# %%
songs.columns
# Out:
# Index(['track_id', 'title', 'song_id', 'release', 'artist_id', 'artist_mbid',
#        'artist_name', 'duration', 'artist_familiarity', 'artist_hotttnesss',
#        'year', 'track_7digitalid', 'shs_perf', 'shs_work'],
#       dtype='object')

# %% [markdown]
# This is a little silly of an example, but you have to use a totally different method entirely to make a scatterplot:

# %%
plt.scatter(songs_per_year["year"], songs_per_year["count"])

# %% [markdown]
# Just to have something to do let's try and look at the number of albums per year at the same time.

# %%
albums_per_year = (songs
 .query('year >= 1900')
 .eval('dummy = 1')
 .groupby(['release','year'], as_index=False)
 .agg({'dummy':'count'})
 .eval('dummy = 1')
 .groupby('year', as_index=False)
 .agg({'dummy':'count'})
 .rename(columns={'dummy':'count'})
 .sort_values('year'))
albums_per_year
# Out:
#     year  count
# 0   1922      3
# 1   1924      4
# 2   1925      7
# 3   1926     15
# 4   1927     33
# ..   ...    ...
# 84  2007   8545
# 85  2008   7537
# 86  2009   6159
# 87  2010   2040
# 88  2011      1
#
# [89 rows x 2 columns]

# %% [markdown]
# Now that we have these two, related, data sets let's go ahead and do a join:

# %%
count_data = albums_per_year.join(songs_per_year.set_index("year"), on=["year"], how="inner", lsuffix="_albums", rsuffix="_songs")
count_data
# Out:
#     year  count_albums  count_songs
# 0   1922             3            6
# 1   1924             4            5
# 2   1925             7            7
# 3   1926            15           19
# 4   1927            33           43
# ..   ...           ...          ...
# 84  2007          8545        39414
# 85  2008          7537        34770
# 86  2009          6159        31051
# 87  2010          2040         9397
# 88  2011             1            1
#
# [89 rows x 3 columns]

# %%
plt.scatter(count_data["year"],count_data["count_albums"],c=count_data["count_songs"])

# %% [markdown]
# Of course, this is a little silly - we probably should calculate average album length per year and normalize these colors somehow, but whatever.

# %% [markdown]
# For the sake of brevity I will not bore you with extensive demonstrations of plotting with Matplotlib or Plotly, though will will look at Bokeh in greater detail soon.
#
# But the idea with these libraries is, fundamentally, the same as in Matplotlib, although with different amounts of scut-work: you must identify the plot type you want, find the appropriate function from the package, and customize the plot with keyword arguments.
#
# Pandasqsl & SQLDF
# =================
#
# Both R and Python provide libraries which allow you to use SQL (lite) on Dataframes Directly. They work very similarly.

# %%
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

pysqldf("select * from count_data limit 10")
# Out:
#    year  count_albums  count_songs
# 0  1922             3            6
# 1  1924             4            5
# 2  1925             7            7
# 3  1926            15           19
# 4  1927            33           43
# 5  1928            38           52
# 6  1929            65           93
# 7  1930            30           40
# 8  1931            21           35
# 9  1932             9           11

# %% [markdown]
# It is as simple as that - note that we are actually playing a little with the global environment in this example. In general, when you invoke sqldf you will need to provide a dictionary with the data frames in it. As a more complicated example (relevant to the homework):

# %%
sqldf("""select a.year, a.count as count_albums, s.count as count_songs from album_counts a
      join song_counts s on a.year = s.year""", {"album_counts":albums_per_year, 
                                                 "song_counts":songs_per_year})
# Out:
#     year  count_albums  count_songs
# 0   1922             3            6
# 1   1924             4            5
# 2   1925             7            7
# 3   1926            15           19
# 4   1927            33           43
# ..   ...           ...          ...
# 84  2007          8545        39414
# 85  2008          7537        34770
# 86  2009          6159        31051
# 87  2010          2040         9397
# 88  2011             1            1
#
# [89 rows x 3 columns]
